# %%
# %tensorflow_version 2.x
import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
import numpy as np
np.sin(np.pi / 2)
np.cos(np.pi / 2)
# Out:
# 6.123233995736766e-17
