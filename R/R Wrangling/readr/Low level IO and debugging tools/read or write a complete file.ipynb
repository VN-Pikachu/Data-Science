# %%
library(tidyverse)

# %% [markdown]
# # Read/write a complete file

# %% [markdown]
# * **`read_file()`** reads a complete file into a single object: either a character vector of length one, or a raw vector.
# * **`write_file()`** takes a single string, or a raw vector, and writes it exactly as is. Raw vectors are useful when dealing with binary data, or if you have text data with unknown encoding.

# %% [markdown]
# ```r
# read_file(file, locale = default_locale())
#
# read_file_raw(file)
#
# write_file(x, file, append = FALSE, path = deprecated())
# ```

# %% [markdown]
# **Arguments**
# `x`
# A single string, or a raw vector to write to disk.
#
# `append`
# If FALSE, will overwrite existing file. If TRUE, will append to existing file. In both cases, if the file does not exist a new file is created.

# %% [markdown]
# # Examples

# %%
mtcars_path <- readr_example('mtcars.csv')

mtcars_path
# Out:
# [1] "C:/Users/dell/Anaconda3/Lib/R/library/readr/extdata/mtcars.csv"

# %%
# a 
read_file(mtcars_path)
# Out:
# [1] "\"mpg\",\"cyl\",\"disp\",\"hp\",\"drat\",\"wt\",\"qsec\",\"vs\",\"am\",\"gear\",\"carb\"\n21,6,160,110,3.9,2.62,16.46,0,1,4,4\n21,6,160,110,3.9,2.875,17.02,0,1,4,4\n22.8,4,108,93,3.85,2.32,18.61,1,1,4,1\n21.4,6,258,110,3.08,3.215,19.44,1,0,3,1\n18.7,8,360,175,3.15,3.44,17.02,0,0,3,2\n18.1,6,225,105,2.76,3.46,20.22,1,0,3,1\n14.3,8,360,245,3.21,3.57,15.84,0,0,3,4\n24.4,4,146.7,62,3.69,3.19,20,1,0,4,2\n22.8,4,140.8,95,3.92,3.15,22.9,1,0,4,2\n19.2,6,167.6,123,3.92,3.44,18.3,1,0,4,4\n17.8,6,167.6,123,3.92,3.44,18.9,1,0,4,4\n16.4,8,275.8,180,3.07,4.07,17.4,0,0,3,3\n17.3,8,275.8,180,3.07,3.73,17.6,0,0,3,3\n15.2,8,275.8,180,3.07,3.78,18,0,0,3,3\n10.4,8,472,205,2.93,5.25,17.98,0,0,3,4\n10.4,8,460,215,3,5.424,17.82,0,0,3,4\n14.7,8,440,230,3.23,5.345,17.42,0,0,3,4\n32.4,4,78.7,66,4.08,2.2,19.47,1,1,4,1\n30.4,4,75.7,52,4.93,1.615,18.52,1,1,4,2\n33.9,4,71.1,65,4.22,1.835,19.9,1,1,4,1\n21.5,4,120.1,97,3.7,2.465,20.01,1,0,3,1\n15.5,8,318,150,2.76,3.52,16.87,0,0,3,2\n15.2,8,304,150,3.15,3.435,1
# ...

# %%
read_file_raw(mtcars_path)
# Out:
#    [1] 22 6d 70 67 22 2c 22 63 79 6c 22 2c 22 64 69 73 70 22 2c 22 68 70 22 2c
#   [25] 22 64 72 61 74 22 2c 22 77 74 22 2c 22 71 73 65 63 22 2c 22 76 73 22 2c
#   [49] 22 61 6d 22 2c 22 67 65 61 72 22 2c 22 63 61 72 62 22 0a 32 31 2c 36 2c
#   [73] 31 36 30 2c 31 31 30 2c 33 2e 39 2c 32 2e 36 32 2c 31 36 2e 34 36 2c 30
#   [97] 2c 31 2c 34 2c 34 0a 32 31 2c 36 2c 31 36 30 2c 31 31 30 2c 33 2e 39 2c
#  [121] 32 2e 38 37 35 2c 31 37 2e 30 32 2c 30 2c 31 2c 34 2c 34 0a 32 32 2e 38
#  [145] 2c 34 2c 31 30 38 2c 39 33 2c 33 2e 38 35 2c 32 2e 33 32 2c 31 38 2e 36
#  [169] 31 2c 31 2c 31 2c 34 2c 31 0a 32 31 2e 34 2c 36 2c 32 35 38 2c 31 31 30
#  [193] 2c 33 2e 30 38 2c 33 2e 32 31 35 2c 31 39 2e 34 34 2c 31 2c 30 2c 33 2c
#  [217] 31 0a 31 38 2e 37 2c 38 2c 33 36 30 2c 31 37 35 2c 33 2e 31 35 2c 33 2e
#  [241] 34 34 2c 31 37 2e 30 32 2c 30 2c 30 2c 33 2c 32 0a 31 38 2e 31 2c 36 2c
#  [265] 32 32 35 2c 31 30 35 2c 32 2e 37 36 2c 33 2e 34 36 2c 32 30 2e 32 32 2c
# ...
