# %%
library(tidyverse)

# %% [markdown]
# # Re-run expressions multiple times.

# %% [markdown]
# This is a convenient way of generating sample data. It works similarly to `replicate(..., simplify = FALSE)`.

# %% [markdown]
# ```r
# rerun(.n, ...)
# ```

# %% [markdown]
# **Arguments**
# `.n`
# Number of times to run expressions
#
# `...`
# Expressions to re-run.

# %% [markdown]
# # Examples

# %%
# rerun 10 times

rerun(10, rnorm(5))
# Out:
# [[1]]
# [1] -1.57041281  2.22891624 -1.08932828  0.51909579 -0.02274121
#
# [[2]]
# [1]  1.6947587 -0.8075484 -0.3216372  1.1656230 -0.1832146
#
# [[3]]
# [1]  0.9829134 -2.5201365 -1.4653129 -0.5003475 -1.4190867
#
# [[4]]
# [1] -0.44669205 -0.65907402 -0.05087871 -1.52845596 -0.01089875
#
# [[5]]
# [1] -0.58679951 -1.10858918 -0.06454503 -0.10801126  1.79662148
#
# [[6]]
# [1]  0.03179403 -0.11411255  0.77038764 -0.41881014 -0.26133785
#
# [[7]]
# [1] -0.8033721 -1.2693537 -2.5049109  0.5322632  0.9615511
#
# [[8]]
# [1]  1.6546985 -0.7833810  1.5047423  0.9759926  0.8481426
#
# [[9]]
# [1]  0.5686958  0.4976301  0.4052060  0.3322465 -0.1365139
#
# [[10]]
# [1] 1.17050442 0.87233631 2.51871578 0.05034748 0.52718894

# %%
rerun(5, sample(letters, 3))
# Out:
# [[1]]
# [1] "d" "l" "u"
#
# [[2]]
# [1] "o" "u" "j"
#
# [[3]]
# [1] "k" "b" "q"
#
# [[4]]
# [1] "s" "e" "x"
#
# [[5]]
# [1] "d" "o" "n"
