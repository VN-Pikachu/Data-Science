# %%
library(tidyverse)

# %% [markdown]
# # Extract a single column

# %% [markdown]
# **`pull()`** is similar to $. It's mostly useful because it looks a little nicer in pipes, it also works with remote data frames, and it can optionally name the output.

# %% [markdown]
# ```R
# pull(.data, var = -1, name = NULL, ...)
# ```

# %% [markdown]
# # Examples

# %%
#select first column of `iris`
iris %>% pull(1)
# Out:
#   [1] 5.1 4.9 4.7 4.6 5.0 5.4 4.6 5.0 4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  [19] 5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.0 5.0 5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.0
#  [37] 5.5 4.9 4.4 5.1 5.0 4.5 4.4 5.0 5.1 4.8 5.1 4.6 5.3 5.0 7.0 6.4 6.9 5.5
#  [55] 6.5 5.7 6.3 4.9 6.6 5.2 5.0 5.9 6.0 6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  [73] 6.3 6.1 6.4 6.6 6.8 6.7 6.0 5.7 5.5 5.5 5.8 6.0 5.4 6.0 6.7 6.3 5.6 5.5
#  [91] 5.5 6.1 5.8 5.0 5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
# [109] 6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.0 6.9 5.6 7.7 6.3 6.7 7.2
# [127] 6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.0 6.9 6.7 6.9 5.8 6.8
# [145] 6.7 6.7 6.3 6.5 6.2 5.9

# %%
iris %>% pull(var = 1)
# Out:
#   [1] 5.1 4.9 4.7 4.6 5.0 5.4 4.6 5.0 4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  [19] 5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.0 5.0 5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.0
#  [37] 5.5 4.9 4.4 5.1 5.0 4.5 4.4 5.0 5.1 4.8 5.1 4.6 5.3 5.0 7.0 6.4 6.9 5.5
#  [55] 6.5 5.7 6.3 4.9 6.6 5.2 5.0 5.9 6.0 6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  [73] 6.3 6.1 6.4 6.6 6.8 6.7 6.0 5.7 5.5 5.5 5.8 6.0 5.4 6.0 6.7 6.3 5.6 5.5
#  [91] 5.5 6.1 5.8 5.0 5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
# [109] 6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.0 6.9 5.6 7.7 6.3 6.7 7.2
# [127] 6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.0 6.9 6.7 6.9 5.8 6.8
# [145] 6.7 6.7 6.3 6.5 6.2 5.9

# %%
#select last column or `iris`: Default
iris %>% pull(-1)
# Out:
#   [1] setosa     setosa     setosa     setosa     setosa     setosa
#   [7] setosa     setosa     setosa     setosa     setosa     setosa
#  [13] setosa     setosa     setosa     setosa     setosa     setosa
#  [19] setosa     setosa     setosa     setosa     setosa     setosa
#  [25] setosa     setosa     setosa     setosa     setosa     setosa
#  [31] setosa     setosa     setosa     setosa     setosa     setosa
#  [37] setosa     setosa     setosa     setosa     setosa     setosa
#  [43] setosa     setosa     setosa     setosa     setosa     setosa
#  [49] setosa     setosa     versicolor versicolor versicolor versicolor
#  [55] versicolor versicolor versicolor versicolor versicolor versicolor
#  [61] versicolor versicolor versicolor versicolor versicolor versicolor
#  [67] versicolor versicolor versicolor versicolor versicolor versicolor
#  [73] versicolor versicolor versicolor versicolor versicolor versicolor
#  [79] versicolor versicolor versicolor versicolor versicolor versicolor
#  [85] versicolor versicolor versicolor versicolor versicolor versicolor
#  [91] versicolor versicolor versicolor versicolor versicolor versicolor
#  [97] versicolor versicolor versicolor versicolor virginica  virginica
# [103] virginica  virginica  virginica  virginica  virginica  virginica
# [109] virginica  virginica  virginica  virginica  virginica  virginica
# [115] virginica  virginica  virginica  virginica  virginica  virginica
# [121] virginica  virginica  virginica  virginica  virginica  virginica
# [127] virginica  virginica  virginica  virginica  virginica  virginica
# [133] virginica  virginica  virginica  virginica  virginica  virginica
# [139] virginica  virginica  virginica  virginica  virginica  virginica
# [145] virginica  virginica  virginica  virginica  virginica  virginica
# Levels: setosa versicolor virginica

# %%
#select column `cyl` from `mpg`
mpg %>% pull(cyl)
# Out:
#   [1] 4 4 4 4 6 6 6 4 4 4 4 6 6 6 6 6 6 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 4 4 6 6 6
#  [38] 4 6 6 6 6 6 6 6 6 6 6 6 6 6 6 8 8 8 8 8 6 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  [75] 8 8 8 6 6 6 6 8 8 6 6 8 8 8 8 8 6 6 6 6 8 8 8 8 8 4 4 4 4 4 4 4 4 4 4 4 4
# [112] 4 6 6 6 4 4 4 4 6 6 6 6 6 6 8 8 8 8 8 8 8 8 8 8 8 8 6 6 8 8 4 4 4 4 6 6 6
# [149] 6 6 6 6 6 8 6 6 6 6 8 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 6 6 6 8 4 4 4 4 6 6
# [186] 6 4 4 4 4 6 6 6 4 4 4 4 4 8 8 4 4 4 6 6 6 6 4 4 4 4 6 4 4 4 4 4 5 5 6 6 4
# [223] 4 4 4 5 5 4 4 4 4 6 6 6

# %% [markdown]
# Pull a named vector

# %%
data.frame(
    clan = c('VNC', 'VNC', 'VN', 'VN'),
    player = c('Meomeo888', 'VN Pikachu', 'VNC Son La TF', 'VN Wanie'),
    level = c(32, 31, 33, 33)
) %>%
pull(player, clan)
# Out:
#           VNC           VNC            VN            VN
#     Meomeo888    VN Pikachu VNC Son La TF      VN Wanie
# Levels: Meomeo888 VN Pikachu VN Wanie VNC Son La TF

# %% [markdown]
# # Arguments

# %% [markdown]
# ### `.data`

# %% [markdown]
# A data frame, data frame extension (e.g. a tibble), or a lazy data frame (e.g. from dbplyr or dtplyr). See Methods, below, for more details.

# %% [markdown]
# ### `var`

# %% [markdown]
#
# A variable specified as:
#
# * a literal variable name
#
# * a positive integer, giving the position counting from the left
#
# * a negative integer, giving the position counting from the right.
#
# The default returns the last column (on the assumption that's the column you've created most recently).
#
# This argument is taken by expression and supports quasiquotation (you can unquote column names and column locations).

# %% [markdown]
# <hr>

# %%
iris %>% head()
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %% [markdown]
# a literal variable name

# %%
iris %>% pull('Sepal.Length')
# Out:
#   [1] 5.1 4.9 4.7 4.6 5.0 5.4 4.6 5.0 4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  [19] 5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.0 5.0 5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.0
#  [37] 5.5 4.9 4.4 5.1 5.0 4.5 4.4 5.0 5.1 4.8 5.1 4.6 5.3 5.0 7.0 6.4 6.9 5.5
#  [55] 6.5 5.7 6.3 4.9 6.6 5.2 5.0 5.9 6.0 6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  [73] 6.3 6.1 6.4 6.6 6.8 6.7 6.0 5.7 5.5 5.5 5.8 6.0 5.4 6.0 6.7 6.3 5.6 5.5
#  [91] 5.5 6.1 5.8 5.0 5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
# [109] 6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.0 6.9 5.6 7.7 6.3 6.7 7.2
# [127] 6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.0 6.9 6.7 6.9 5.8 6.8
# [145] 6.7 6.7 6.3 6.5 6.2 5.9

# %% [markdown]
# a positive integer, giving the position counting from the left

# %%
#the second column from left to right: Sepal.Width
iris %>% pull(2)
# Out:
#   [1] 3.5 3.0 3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.0 3.0 4.0 4.4 3.9 3.5
#  [19] 3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.0 3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#  [37] 3.5 3.6 3.0 3.4 3.5 2.3 3.2 3.5 3.8 3.0 3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#  [55] 2.8 2.8 3.3 2.4 2.9 2.7 2.0 3.0 2.2 2.9 2.9 3.1 3.0 2.7 2.2 2.5 3.2 2.8
#  [73] 2.5 2.8 2.9 3.0 2.8 3.0 2.9 2.6 2.4 2.4 2.7 2.7 3.0 3.4 3.1 2.3 3.0 2.5
#  [91] 2.6 3.0 2.6 2.3 2.7 3.0 2.9 2.9 2.5 2.8 3.3 2.7 3.0 2.9 3.0 3.0 2.5 2.9
# [109] 2.5 3.6 3.2 2.7 3.0 2.5 2.8 3.2 3.0 3.8 2.6 2.2 3.2 2.8 2.8 2.7 3.3 3.2
# [127] 2.8 3.0 2.8 3.0 2.8 3.8 2.8 2.8 2.6 3.0 3.4 3.1 3.0 3.1 3.1 3.1 2.7 3.2
# [145] 3.3 3.0 2.5 3.0 3.4 3.0

# %% [markdown]
# a negative integer, giving the position counting from the right.

# %%
#The last column
iris %>% pull(-1)
# Out:
#   [1] setosa     setosa     setosa     setosa     setosa     setosa
#   [7] setosa     setosa     setosa     setosa     setosa     setosa
#  [13] setosa     setosa     setosa     setosa     setosa     setosa
#  [19] setosa     setosa     setosa     setosa     setosa     setosa
#  [25] setosa     setosa     setosa     setosa     setosa     setosa
#  [31] setosa     setosa     setosa     setosa     setosa     setosa
#  [37] setosa     setosa     setosa     setosa     setosa     setosa
#  [43] setosa     setosa     setosa     setosa     setosa     setosa
#  [49] setosa     setosa     versicolor versicolor versicolor versicolor
#  [55] versicolor versicolor versicolor versicolor versicolor versicolor
#  [61] versicolor versicolor versicolor versicolor versicolor versicolor
#  [67] versicolor versicolor versicolor versicolor versicolor versicolor
#  [73] versicolor versicolor versicolor versicolor versicolor versicolor
#  [79] versicolor versicolor versicolor versicolor versicolor versicolor
#  [85] versicolor versicolor versicolor versicolor versicolor versicolor
#  [91] versicolor versicolor versicolor versicolor versicolor versicolor
#  [97] versicolor versicolor versicolor versicolor virginica  virginica
# [103] virginica  virginica  virginica  virginica  virginica  virginica
# [109] virginica  virginica  virginica  virginica  virginica  virginica
# [115] virginica  virginica  virginica  virginica  virginica  virginica
# [121] virginica  virginica  virginica  virginica  virginica  virginica
# [127] virginica  virginica  virginica  virginica  virginica  virginica
# [133] virginica  virginica  virginica  virginica  virginica  virginica
# [139] virginica  virginica  virginica  virginica  virginica  virginica
# [145] virginica  virginica  virginica  virginica  virginica  virginica
# Levels: setosa versicolor virginica

# %% [markdown]
# ### `name`

# %% [markdown]
# An optional parameter that specifies the column to be used as names for a named vector. Specified in a similar manner as var.

# %%
#create a named vector in which levels is column Species and values is column Sepal.Width

iris %>% pull(var = 'Sepal.Width', name = -1)
# Out:
#     setosa     setosa     setosa     setosa     setosa     setosa     setosa
#        3.5        3.0        3.2        3.1        3.6        3.9        3.4
#     setosa     setosa     setosa     setosa     setosa     setosa     setosa
#        3.4        2.9        3.1        3.7        3.4        3.0        3.0
#     setosa     setosa     setosa     setosa     setosa     setosa     setosa
#        4.0        4.4        3.9        3.5        3.8        3.8        3.4
#     setosa     setosa     setosa     setosa     setosa     setosa     setosa
#        3.7        3.6        3.3        3.4        3.0        3.4        3.5
#     setosa     setosa     setosa     setosa     setosa     setosa     setosa
#        3.4        3.2        3.1        3.4        4.1        4.2        3.1
#     setosa     setosa     setosa     setosa     setosa     setosa     setosa
#        3.2        3.5        3.6        3.0        3.4        3.5        2.3
#     setosa     setosa     setosa     setosa     setosa     setosa     setosa
#        3.2        3.5        3.8        3.0        3.8        3.2        3.7
#     setosa versicolor versicolor versicolor versicolor versicolor versicolor
#        3.3        3.2        3.2        3.1        2.3        2.8        2.8
# versicolor versicolor versicolor versicolor versicolor versicolor versicolor
#        3.3        2.4        2.9        2.7        2.0        3.0        2.2
# versicolor versicolor versicolor versicolor versicolor versicolor versicolor
#        2.9        2.9        3.1        3.0        2.7        2.2        2.5
# versicolor versicolor versicolor versicolor versicolor versicolor versicolor
#        3.2        2.8        2.5        2.8        2.9        3.0        2.8
# versicolor versicolor versicolor versicolor versicolor versicolor versicolor
#        3.0        2.9        2.6        2.4        2.4        2.7        2.7
# versicolor versicolor versicolor versicolor versicolor versicolor versicolor
#        3.0        3.4        3.1        2.3        3.0        2.5        2.6
# versicolor versicolor versicolor versicolor versicolor versicolor versicolor
#        3.0        2.6        2.3        2.7        3.0        2.9        2.9
# versicolor versicolor  virginica  virginica  virginica  virginica  virginica
#        2.5        2.8        3.3        2.7        3.0        2.9        3.0
#  virginica  virginica  virginica  virginica  virginica  virginica  virginica
#        3.0        2.5        2.9        2.5        3.6        3.2        2.7
#  virginica  virginica  virginica  virginica  virginica  virginica  virginica
#        3.0        2.5        2.8        3.2        3.0        3.8        2.6
#  virginica  virginica  virginica  virginica  virginica  virginica  virginica
#        2.2        3.2        2.8        2.8        2.7        3.3        3.2
#  virginica  virginica  virginica  virginica  virginica  virginica  virginica
#        2.8        3.0        2.8        3.0        2.8        3.8        2.8
#  virginica  virginica  virginica  virginica  virginica  virginica  virginica
#        2.8        2.6        3.0        3.4        3.1        3.0        3.1
#  virginica  virginica  virginica  virginica  virginica  virginica  virginica
#        3.1        3.1        2.7        3.2        3.3        3.0        2.5
#  virginica  virginica  virginica
#        3.0        3.4        3.0

# %% [markdown]
# ### `...`

# %% [markdown]
# For use by methods.
