# %%
library(tidyverse)

# %% [markdown]
# # Do values in a numeric vector fall in specified range?

# %% [markdown]
# This is a shortcut for x >= left & x <= right, implemented efficiently in C++ for local values, and translated to the appropriate SQL for remote tables.

# %% [markdown]
# ```R
# between(x, left, right)
# ```

# %% [markdown]
# # Examples

# %%
between(1:12, 7, 9)
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE FALSE FALSE FALSE

# %%
#select cars having `cyl` between 4 and 6
mpg %>% 
filter(between(cyl, 4, 6))
# Out:
#     manufacturer model             displ year cyl trans      drv cty hwy fl
# 1   audi         a4                1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro        1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro        1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro        2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro        2.0   2008 4   auto(s6)   4   19  27  p
# 12  audi         a4 quattro        2.8   1999 6   auto(l5)   4   15  25  p
# 13  audi         a4 quattro        2.8   1999 6   manual(m5) 4   17  25  p
# 14  audi         a4 quattro        3.1   2008 6   auto(s6)   4   17  25  p
# 15  audi         a4 quattro        3.1   2008 6   manual(m6) 4   15  25  p
# 16  audi         a6 quattro        2.8   1999 6   auto(l5)   4   15  24  p
# 17  audi         a6 quattro        3.1   2008 6   auto(s6)   4   17  25  p
# 18  chevrolet    malibu            2.4   1999 4   auto(l4)   f   19  27  r
# 19  chevrolet    malibu            2.4   2008 4   auto(l4)   f   22  30  r
# 20  chevrolet    malibu            3.1   1999 6   auto(l4)   f   18  26  r
# 21  chevrolet    malibu            3.5   2008 6   auto(l4)   f   18  29  r
# 22  chevrolet    malibu            3.6   2008 6   auto(s6)   f   17  26  r
# 23  dodge        caravan 2wd       2.4   1999 4   auto(l3)   f   18  24  r
# 24  dodge        caravan 2wd       3.0   1999 6   auto(l4)   f   17  24  r
# 25  dodge        caravan 2wd       3.3   1999 6   auto(l4)   f   16  22  r
# 26  dodge        caravan 2wd       3.3   1999 6   auto(l4)   f   16  22  r
# 27  dodge        caravan 2wd       3.3   2008 6   auto(l4)   f   17  24  r
# 28  dodge        caravan 2wd       3.3   2008 6   auto(l4)   f   17  24  r
# 29  dodge        caravan 2wd       3.3   2008 6   auto(l4)   f   11  17  e
# 30  dodge        caravan 2wd       3.8   1999 6   auto(l4)   f   15  22  r
# ... ...          ...               ...   ...  ... ...        ... ... ... ...
# 135 toyota       toyota tacoma 4wd 3.4   1999 6   auto(l4)   4   15  19  r
# 136 toyota       toyota tacoma 4wd 4.0   2008 6   manual(m6) 4   15  18  r
# 137 toyota       toyota tacoma 4wd 4.0   2008 6   auto(l5)   4   16  20  r
# 138 volkswagen   gti               2.0   1999 4   manual(m5) f   21  29  r
# 139 volkswagen   gti               2.0   1999 4   auto(l4)   f   19  26  r
# 140 volkswagen   gti               2.0   2008 4   manual(m6) f   21  29  p
# 141 volkswagen   gti               2.0   2008 4   auto(s6)   f   22  29  p
# 142 volkswagen   gti               2.8   1999 6   manual(m5) f   17  24  r
# 143 volkswagen   jetta             1.9   1999 4   manual(m5) f   33  44  d
# 144 volkswagen   jetta             2.0   1999 4   manual(m5) f   21  29  r
# 145 volkswagen   jetta             2.0   1999 4   auto(l4)   f   19  26  r
# 146 volkswagen   jetta             2.0   2008 4   auto(s6)   f   22  29  p
# 147 volkswagen   jetta             2.0   2008 4   manual(m6) f   21  29  p
# 148 volkswagen   jetta             2.5   2008 5   auto(s6)   f   21  29  r
# 149 volkswagen   jetta             2.5   2008 5   manual(m5) f   21  29  r
# 150 volkswagen   jetta             2.8   1999 6   auto(l4)   f   16  23  r
# 151 volkswagen   jetta             2.8   1999 6   manual(m5) f   17  24  r
# 152 volkswagen   new beetle        1.9   1999 4   manual(m5) f   35  44  d
# 153 volkswagen   new beetle        1.9   1999 4   auto(l4)   f   29  41  d
# 154 volkswagen   new beetle        2.0   1999 4   manual(m5) f   21  29  r
# 155 volkswagen   new beetle        2.0   1999 4   auto(l4)   f   19  26  r
# 156 volkswagen   new beetle        2.5   2008 5   manual(m5) f   20  28  r
# 157 volkswagen   new beetle        2.5   2008 5   auto(s6)   f   20  29  r
# 158 volkswagen   passat            1.8   1999 4   manual(m5) f   21  29  p
# 159 volkswagen   passat            1.8   1999 4   auto(l5)   f   18  29  p
# 160 volkswagen   passat            2.0   2008 4   auto(s6)   f   19  28  p
# 161 volkswagen   passat            2.0   2008 4   manual(m6) f   21  29  p
# 162 volkswagen   passat            2.8   1999 6   auto(l5)   f   16  26  p
# 163 volkswagen   passat            2.8   1999 6   manual(m5) f   18  26  p
# 164 volkswagen   passat            3.6   2008 6   auto(s6)   f   17  26  p
#     class
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact
# 6   compact
# 7   compact
# 8   compact
# 9   compact
# 10  compact
# 11  compact
# 12  compact
# 13  compact
# 14  compact
# 15  compact
# 16  midsize
# 17  midsize
# 18  midsize
# 19  midsize
# 20  midsize
# 21  midsize
# 22  midsize
# 23  minivan
# 24  minivan
# 25  minivan
# 26  minivan
# 27  minivan
# 28  minivan
# 29  minivan
# 30  minivan
# ... ...
# 135 pickup
# 136 pickup
# 137 pickup
# 138 compact
# 139 compact
# 140 compact
# 141 compact
# 142 compact
# 143 compact
# 144 compact
# 145 compact
# 146 compact
# 147 compact
# 148 compact
# 149 compact
# 150 compact
# 151 compact
# 152 subcompact
# 153 subcompact
# 154 subcompact
# 155 subcompact
# 156 subcompact
# 157 subcompact
# 158 midsize
# 159 midsize
# 160 midsize
# 161 midsize
# 162 midsize
# 163 midsize
# 164 midsize
