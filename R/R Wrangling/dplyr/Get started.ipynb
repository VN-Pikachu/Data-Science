# %%
library(tidyverse)

# %% [markdown]
# # Dataset

# %% [markdown]
# starwars:

# %%
glimpse(starwars)
# Out:
# Rows: 87
# Columns: 14
# $ name       <chr> "Luke Skywalker", "C-3PO", "R2-D2", "Darth Vader", "Leia...
# $ height     <int> 172, 167, 96, 202, 150, 178, 165, 97, 183, 182, 188, 180...
# $ mass       <dbl> 77.0, 75.0, 32.0, 136.0, 49.0, 120.0, 75.0, 32.0, 84.0, ...
# $ hair_color <chr> "blond", NA, NA, "none", "brown", "brown, grey", "brown"...
# $ skin_color <chr> "fair", "gold", "white, blue", "white", "light", "light"...
# $ eye_color  <chr> "blue", "yellow", "red", "yellow", "brown", "blue", "blu...
# $ birth_year <dbl> 19.0, 112.0, 33.0, 41.9, 19.0, 52.0, 47.0, NA, 24.0, 57....
# $ sex        <chr> "male", "none", "none", "male", "female", "male", "femal...
# $ gender     <chr> "masculine", "masculine", "masculine", "masculine", "fem...
# $ homeworld  <chr> "Tatooine", "Tatooine", "Naboo", "Tatooine", "Alderaan",...
# $ species    <chr> "Human", "Droid", "Droid", "Human", "Human", "Human", "H...
# $ films      <list> [<"The Empire Strikes Back", "Revenge of the Sith", "Re...
# ...

# %%
starwars %>% head()
# Out:
#   name           height mass hair_color  skin_color  eye_color birth_year
# 1 Luke Skywalker 172     77  blond       fair        blue       19.0
# 2 C-3PO          167     75  NA          gold        yellow    112.0
# 3 R2-D2           96     32  NA          white, blue red        33.0
# 4 Darth Vader    202    136  none        white       yellow     41.9
# 5 Leia Organa    150     49  brown       light       brown      19.0
# 6 Owen Lars      178    120  brown, grey light       blue       52.0
#   sex    gender    homeworld species
# 1 male   masculine Tatooine  Human
# 2 none   masculine Tatooine  Droid
# 3 none   masculine Naboo     Droid
# 4 male   masculine Tatooine  Human
# 5 female feminine  Alderaan  Human
# 6 male   masculine Tatooine  Human
#   films
# 1 The Empire Strikes Back, Revenge of the Sith    , Return of the Jedi     , A New Hope             , The Force Awakens
# ...

# %% [markdown]
# # Single table verbs

# %% [markdown]
# dplyr aims to provide a function for each basic verb of data manipulation. These verbs can be organised into three categories based on the component of the dataset that they work with:
#
# * Rows:
#   * `filter()` chooses rows based on column values.
#   * `slice()` chooses rows based on location.
#   * `arrange()` changes the order of the rows.
# * Columns:
#     * `select()` changes whether or not a column is included.
#     * `rename()` changes the name of columns.
#     * `mutate()` changes the values of columns and creates new columns.
#     * `relocate()` changes the order of the columns.
# * Groups of rows:
#     * `summarise()` collapses a group into a single row.

# %% [markdown]
# # The pipe

# %% [markdown]
# **`%>%`**

# %% [markdown]
# # Filter rows with `filter()`

# %% [markdown]
# **`filter()`** allows you to select a subset of rows in a data frame.
# For example, we can select all character with light skin color and brown eyes with:

# %%
starwars %>% filter(skin_color == 'light' & eye_color == 'brown')
# Out:
#   name              height mass hair_color skin_color eye_color birth_year
# 1 Leia Organa       150    49   brown      light      brown     19
# 2 Biggs Darklighter 183    84   black      light      brown     24
# 3 Cordé             157    NA   brown      light      brown     NA
# 4 Dormé             165    NA   brown      light      brown     NA
# 5 Raymus Antilles   188    79   brown      light      brown     NA
# 6 Poe Dameron        NA    NA   brown      light      brown     NA
# 7 Padmé Amidala     165    45   brown      light      brown     46
#   sex    gender    homeworld species
# 1 female feminine  Alderaan  Human
# 2 male   masculine Tatooine  Human
# 3 female feminine  Naboo     Human
# 4 female feminine  Naboo     Human
# 5 male   masculine Alderaan  Human
# 6 male   masculine NA        Human
# 7 female feminine  Naboo     Human
#   films
# 1 The Empire Strikes Back, Revenge of the Sith    , Return of the Jedi     , A New Hope             , The Force Awakens
# ...

# %% [markdown]
# # Arrange rows with `arrange()`

# %%
#arrange by mass desc, height asc
starwars %>% arrange(desc(mass), height)
# Out:
#     name                  height mass hair_color   skin_color
# 1   Jabba Desilijic Tiure 175    1358 NA           green-tan, brown
# 2   Grievous              216     159 none         brown, white
# 3   IG-88                 200     140 none         metal
# 4   Darth Vader           202     136 none         white
# 5   Tarfful               234     136 brown        brown
# 6   Owen Lars             178     120 brown, grey  light
# 7   Bossk                 190     113 none         green
# 8   Chewbacca             228     112 brown        unknown
# 9   Jek Tono Porkins      180     110 brown        fair
# 10  Dexter Jettster       198     102 none         brown
# 11  Nute Gunray           191      90 none         mottled green
# 12  Qui-Gon Jinn          193      89 brown        fair
# 13  Lama Su               229      88 none         grey
# 14  Kit Fisto             196      87 none         green
# 15  Gregar Typho          185      85 black        dark
# ...

# %% [markdown]
# # Choose rows using their position with `slice()`

# %% [markdown]
# `slice()` lets you index rows by their (integer) locations. It allows you to:
# * select
# * remove
# * duplicate rows

# %% [markdown]
# We can get characters from row numbers 5 through 10.

# %%
starwars %>% slice(5:10)
# Out:
#   name               height mass hair_color    skin_color eye_color birth_year
# 1 Leia Organa        150     49  brown         light      brown     19
# 2 Owen Lars          178    120  brown, grey   light      blue      52
# 3 Beru Whitesun lars 165     75  brown         light      blue      47
# 4 R5-D4               97     32  NA            white, red red       NA
# 5 Biggs Darklighter  183     84  black         light      brown     24
# 6 Obi-Wan Kenobi     182     77  auburn, white fair       blue-gray 57
#   sex    gender    homeworld species
# 1 female feminine  Alderaan  Human
# 2 male   masculine Tatooine  Human
# 3 female feminine  Tatooine  Human
# 4 none   masculine Tatooine  Droid
# 5 male   masculine Tatooine  Human
# 6 male   masculine Stewjon   Human
#   films
# 1 The Empire Strikes Back, Revenge of the Sith    , Return of the Jedi     , A New Hope             , The Force Awakens
# 2 Attack of the Clones, Revenge of the Sith , A New Hope
# ...

# %% [markdown]
# It is accompanied by a number of helpers for common use cases:
#
# `slice_head()` and `slice_tail()` select the first or last rows.

# %%
#select first 3 rows
starwars %>% slice_head(n = 3)
# Out:
#   name           height mass hair_color skin_color  eye_color birth_year sex
# 1 Luke Skywalker 172    77   blond      fair        blue       19        male
# 2 C-3PO          167    75   NA         gold        yellow    112        none
# 3 R2-D2           96    32   NA         white, blue red        33        none
#   gender    homeworld species
# 1 masculine Tatooine  Human
# 2 masculine Tatooine  Droid
# 3 masculine Naboo     Droid
#   films
# 1 The Empire Strikes Back, Revenge of the Sith    , Return of the Jedi     , A New Hope             , The Force Awakens
# 2 The Empire Strikes Back, Attack of the Clones   , The Phantom Menace     , Revenge of the Sith    , Return of the Jedi     , A New Hope
# 3 The Empire Strikes Back, Attack of the Clones   , The Phantom Menace     , Revenge of the Sith    , Return of the Jedi     , A New Hope             , The Force Awakens
#   vehicles
# 1 Snowspeeder          , Imperial Speeder Bike
# 2
# 3
#   starships
# ...

# %% [markdown]
# `slice_sample()` randomly selects rows. Use the option prop to choose a certain proportion of the cases.

# %%
#randomly sample 5 observations
starwars %>% slice_sample(n = 5)
# Out:
#   name      height mass hair_color skin_color       eye_color birth_year sex
# 1 Watto     137     NA  black      blue, grey       yellow    NA         male
# 2 Kit Fisto 196     87  none       green            black     NA         male
# 3 Shaak Ti  178     57  none       red, blue, white black     NA         female
# 4 BB8        NA     NA  none       none             black     NA         none
# 5 Bossk     190    113  none       green            red       53         male
#   gender    homeworld   species
# 1 masculine Toydaria    Toydarian
# 2 masculine Glee Anselm Nautolan
# 3 feminine  Shili       Togruta
# 4 masculine NA          Droid
# 5 masculine Trandosha   Trandoshan
#   films                                                            vehicles
# 1 Attack of the Clones, The Phantom Menace
# 2 Attack of the Clones, The Phantom Menace  , Revenge of the Sith
# 3 Attack of the Clones, Revenge of the Sith
# 4 The Force Awakens
# 5 The Empire Strikes Back
#   starships
# 1
# 2
# ...

# %%
#randomly sample 10% number of observations
#e.g: If there is 1000 observations, randomly sample 100 observations

starwars %>% slice_sample(prop = .1)
# Out:
#   name           height mass hair_color skin_color  eye_color birth_year sex
# 1 Chewbacca      228    112  brown      unknown     blue      200        male
# 2 Dud Bolt        94     45  none       blue, grey  yellow     NA        male
# 3 Shmi Skywalker 163     NA  black      fair        brown      72        female
# 4 R2-D2           96     32  NA         white, blue red        33        none
# 5 BB8             NA     NA  none       none        black      NA        none
# 6 Mas Amedda     196     NA  none       blue        blue       NA        male
# 7 Leia Organa    150     49  brown      light       brown      19        female
# 8 Taun We        213     NA  none       grey        black      NA        female
#   gender    homeworld species
# 1 masculine Kashyyyk  Wookiee
# 2 masculine Vulpter   Vulptereen
# 3 feminine  Tatooine  Human
# 4 masculine Naboo     Droid
# 5 masculine NA        Droid
# 6 masculine Champala  Chagrian
# 7 feminine  Alderaan  Human
# ...

# %% [markdown]
# Use `replace = TRUE` to perform a bootstrap sample. If needed, you can weight the sample with the `weight` argument.

# %%
#bootstrap
starwars %>% slice_sample(n = 10, replace = T)
# Out:
#    name               height mass hair_color    skin_color   eye_color
# 1  Wat Tambor         193     48  none          green, grey  unknown
# 2  Beru Whitesun lars 165     75  brown         light        blue
# 3  Biggs Darklighter  183     84  black         light        brown
# 4  Grievous           216    159  none          brown, white green, yellow
# 5  Obi-Wan Kenobi     182     77  auburn, white fair         blue-gray
# 6  Grievous           216    159  none          brown, white green, yellow
# 7  Jek Tono Porkins   180    110  brown         fair         blue
# 8  Ackbar             180     83  none          brown mottle orange
# 9  Saesee Tiin        188     NA  none          pale         orange
# 10 Dud Bolt            94     45  none          blue, grey   yellow
#    birth_year sex    gender    homeworld  species
# 1  NA         male   masculine Skako      Skakoan
# 2  47         female feminine  Tatooine   Human
# 3  24         male   masculine Tatooine   Human
# ...

# %% [markdown]
# `slice_min()` and `slice_max()` select rows with highest or lowest values of a variable. Note that we first must choose only the values which are not NA.

# %%
#select 3 hgihest characters
starwars %>% 
filter(!is.na(height)) %>%
slice_max(height, n = 3)
# Out:
#   name        height mass hair_color skin_color eye_color birth_year sex
# 1 Yarael Poof 264     NA  none       white      yellow    NA         male
# 2 Tarfful     234    136  brown      brown      blue      NA         male
# 3 Lama Su     229     88  none       grey       black     NA         male
#   gender    homeworld species  films                vehicles starships
# 1 masculine Quermia   Quermian The Phantom Menace
# 2 masculine Kashyyyk  Wookiee  Revenge of the Sith
# 3 masculine Kamino    Kaminoan Attack of the Clones

# %% [markdown]
# # Select column with `select()`

# %% [markdown]
# Often you work with large datasets with many columns but only a few are actually of interest to you. **`select()`** allows you to rapidly zoom in on a useful subset using operations that usually only work on numeric variable positions:

# %%
# Select columns by name
iris %>% 
select(Sepal.Length, Sepal.Width) %>% head()
# Out:
#   Sepal.Length Sepal.Width
# 1 5.1          3.5
# 2 4.9          3.0
# 3 4.7          3.2
# 4 4.6          3.1
# 5 5.0          3.6
# 6 5.4          3.9

# %%
# Select all columns between hair_color and eye_color (inclusive)
starwars %>% select(hair_color:eye_color)
# Out:
#     hair_color    skin_color          eye_color
# 1   blond         fair                blue
# 2   NA            gold                yellow
# 3   NA            white, blue         red
# 4   none          white               yellow
# 5   brown         light               brown
# 6   brown, grey   light               blue
# 7   brown         light               blue
# 8   NA            white, red          red
# 9   black         light               brown
# 10  auburn, white fair                blue-gray
# 11  blond         fair                blue
# 12  auburn, grey  fair                blue
# 13  brown         unknown             blue
# 14  brown         fair                brown
# 15  NA            green               black
# 16  NA            green-tan, brown    orange
# 17  brown         fair                hazel
# 18  brown         fair                blue
# 19  white         green               brown
# 20  grey          pale                yellow
# ...

# %%
# Select all columns except those from hair_color to eye_color (inclusive)
starwars %>% select(!(hair_color:eye_color))
# Out:
#     name                  height mass   birth_year sex            gender
# 1   Luke Skywalker        172      77.0  19.0      male           masculine
# 2   C-3PO                 167      75.0 112.0      none           masculine
# 3   R2-D2                  96      32.0  33.0      none           masculine
# 4   Darth Vader           202     136.0  41.9      male           masculine
# 5   Leia Organa           150      49.0  19.0      female         feminine
# 6   Owen Lars             178     120.0  52.0      male           masculine
# 7   Beru Whitesun lars    165      75.0  47.0      female         feminine
# 8   R5-D4                  97      32.0    NA      none           masculine
# 9   Biggs Darklighter     183      84.0  24.0      male           masculine
# 10  Obi-Wan Kenobi        182      77.0  57.0      male           masculine
# 11  Anakin Skywalker      188      84.0  41.9      male           masculine
# ...

# %%
# Select all columns ending with color
starwars %>% select(ends_with('color'))
# Out:
#     hair_color    skin_color          eye_color
# 1   blond         fair                blue
# 2   NA            gold                yellow
# 3   NA            white, blue         red
# 4   none          white               yellow
# 5   brown         light               brown
# 6   brown, grey   light               blue
# 7   brown         light               blue
# 8   NA            white, red          red
# 9   black         light               brown
# 10  auburn, white fair                blue-gray
# 11  blond         fair                blue
# 12  auburn, grey  fair                blue
# 13  brown         unknown             blue
# 14  brown         fair                brown
# 15  NA            green               black
# 16  NA            green-tan, brown    orange
# 17  brown         fair                hazel
# 18  brown         fair                blue
# 19  white         green               brown
# 20  grey          pale                yellow
# ...

# %% [markdown]
# You can rename variables with `select()` by using named arguments:

# %%
starwars %>% select(eye.color = eye_color) %>% head()
# Out:
#   eye.color
# 1 blue
# 2 yellow
# 3 red
# 4 yellow
# 5 brown
# 6 blue

# %% [markdown]
# But because `select()` drops all the variables not explicitly mentioned, it’s not that useful. Instead, use `rename()`:

# %%
starwars %>% rename(eye.color = eye_color, hair.color = hair_color)
# Out:
#     name                  height mass   hair.color    skin_color
# 1   Luke Skywalker        172      77.0 blond         fair
# 2   C-3PO                 167      75.0 NA            gold
# 3   R2-D2                  96      32.0 NA            white, blue
# 4   Darth Vader           202     136.0 none          white
# 5   Leia Organa           150      49.0 brown         light
# 6   Owen Lars             178     120.0 brown, grey   light
# 7   Beru Whitesun lars    165      75.0 brown         light
# 8   R5-D4                  97      32.0 NA            white, red
# 9   Biggs Darklighter     183      84.0 black         light
# 10  Obi-Wan Kenobi        182      77.0 auburn, white fair
# 11  Anakin Skywalker      188      84.0 blond         fair
# 12  Wilhuff Tarkin        180        NA auburn, grey  fair
# 13  Chewbacca             228     112.0 brown         unknown
# 14  Han Solo              180      80.0 brown         fair
# ...

# %% [markdown]
# # Add new columns with `mutate()`

# %% [markdown]
# Besides selecting sets of existing columns, it’s often useful to add new columns that are functions of existing columns.

# %%
starwars %>% 
mutate(height_m = height / 100) %>%
select(height_m, height, everything())
# Out:
#     height_m height name                  mass   hair_color
# 1   1.72     172    Luke Skywalker          77.0 blond
# 2   1.67     167    C-3PO                   75.0 NA
# 3   0.96      96    R2-D2                   32.0 NA
# 4   2.02     202    Darth Vader            136.0 none
# 5   1.50     150    Leia Organa             49.0 brown
# 6   1.78     178    Owen Lars              120.0 brown, grey
# 7   1.65     165    Beru Whitesun lars      75.0 brown
# 8   0.97      97    R5-D4                   32.0 NA
# 9   1.83     183    Biggs Darklighter       84.0 black
# 10  1.82     182    Obi-Wan Kenobi          77.0 auburn, white
# 11  1.88     188    Anakin Skywalker        84.0 blond
# 12  1.80     180    Wilhuff Tarkin            NA auburn, grey
# 13  2.28     228    Chewbacca              112.0 brown
# 14  1.80     180    Han Solo                80.0 brown
# 15  1.73     173    Greedo                  74.0 NA
# 16  1.75     175    Jabba Desilijic Tiure 1358.0 NA
# ...

# %% [markdown]
# `dplyr::mutate()` is similar to the base `transform()`, but allows you to refer to columns that you’ve just created:

# %%
starwars %>% 
mutate(height_m = height / 100,
       BMI = mass / height_m ^ 2) %>% 
select(BMI, everything())
# Out:
#     BMI       name                  height mass   hair_color
# 1    26.02758 Luke Skywalker        172      77.0 blond
# 2    26.89232 C-3PO                 167      75.0 NA
# 3    34.72222 R2-D2                  96      32.0 NA
# 4    33.33007 Darth Vader           202     136.0 none
# 5    21.77778 Leia Organa           150      49.0 brown
# 6    37.87401 Owen Lars             178     120.0 brown, grey
# 7    27.54821 Beru Whitesun lars    165      75.0 brown
# 8    34.00999 R5-D4                  97      32.0 NA
# 9    25.08286 Biggs Darklighter     183      84.0 black
# 10   23.24598 Obi-Wan Kenobi        182      77.0 auburn, white
# 11   23.76641 Anakin Skywalker      188      84.0 blond
# 12         NA Wilhuff Tarkin        180        NA auburn, grey
# 13   21.54509 Chewbacca             228     112.0 brown
# 14   24.69136 Han Solo              180      80.0 brown
# 15   24.72518 Greedo                173      74.0 NA
# 16  443.42857 Jabba Desilijic Tiure 175    1358.0 NA
# ...

# %% [markdown]
# If you only want to keep the new variables, use **`transmute()`**:

# %%
starwars %>% 
transmute(height_m = height / 100) %>% head()
# Out:
#   height_m
# 1 1.72
# 2 1.67
# 3 0.96
# 4 2.02
# 5 1.50
# 6 1.78

# %% [markdown]
# # Changing column order with `relocate`

# %%
iris %>% head()
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
#relocate Petal before Sepal

#Using across to `select()` style
iris %>% relocate(starts_with('Sepal'), .after = starts_with('Petal')) %>% head()
# Out:
#   Petal.Length Petal.Width Sepal.Length Sepal.Width Species
# 1 1.4          0.2         5.1          3.5         setosa
# 2 1.4          0.2         4.9          3.0         setosa
# 3 1.3          0.2         4.7          3.2         setosa
# 4 1.5          0.2         4.6          3.1         setosa
# 5 1.4          0.2         5.0          3.6         setosa
# 6 1.7          0.4         5.4          3.9         setosa

# %% [markdown]
# # Summarise values with `summarise()`

# %%
#Calculate the mean of each column for each group of Species
iris %>% 
group_by(Species) %>% 
summarize(across(everything(), mean))
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   Species    Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1 setosa     5.006        3.428       1.462        0.246
# 2 versicolor 5.936        2.770       4.260        1.326
# 3 virginica  6.588        2.974       5.552        2.026

# %% [markdown]
# # Pattern of Operations

# %%
TF <- data.frame(
    clan = c('VNC', 'King Allool'),
    player = c('VN Pikachu', 'xXx-Hadi-xXx')
)

TF
# Out:
#   clan        player
# 1 VNC         VN Pikachu
# 2 King Allool xXx-Hadi-xXx

# %% [markdown]
# ### Selecting operation

# %% [markdown]
# Selecting operations expect column names and positions. Hence, when you call `select()` with bare variable names, they actually represent their own positions in the tibble. The following calls are completely equivalent from dplyr’s point of view:

# %%
TF %>% select(player)
# Out:
#   player
# 1 VN Pikachu
# 2 xXx-Hadi-xXx

# %%
TF %>% select(2)
# Out:
#   player
# 1 VN Pikachu
# 2 xXx-Hadi-xXx

# %% [markdown]
# By the same token, this means that you cannot refer to variables from the surrounding context if they have the same name as one of the columns.

# %%
player <- 1
#This is equivalent to TF %>% select(2), NOT TF %>% select(1), depsite of the assignment above 
TF %>% select(player)
# Out:
#   player
# 1 VN Pikachu
# 2 xXx-Hadi-xXx

# %% [markdown]
# One useful subtlety is that this only applies to bare names and to selecting calls like `c(height, mass)` or `height:mass`. In all other cases, the columns of the data frame are not put in scope. This allows you to refer to contextual variables in selection helpers:

# %%
clan <- 'clan'

TF %>% select(starts_with(clan))
# Out:
#   clan
# 1 VNC
# 2 King Allool

# %% [markdown]
# These semantics are usually intuitive. But note the subtle difference:

# %%
clan <- 2

TF %>% select(clan)           #equivalent to: TF %>% select(1)

TF %>% select(identity(clan)) #equivalent to: TF %>% select(2)
# Out:
#   clan
# 1 VNC
# 2 King Allool
#   player
# 1 VN Pikachu
# 2 xXx-Hadi-xXx

# %% [markdown]
# ### Mutating operations

# %% [markdown]
# When we use `select()`, the bare column names stand for their own positions in the tibble. For `mutate()` on the other hand, column symbols represent the actual column vectors stored in the tibble. Consider what happens if we give a string or a number to `mutate()`:

# %%
TF %>% select('clan')
# Out:
#   clan
# 1 VNC
# 2 King Allool

# %%
TF %>% mutate('clan')
# Out:
#   clan        player       "clan"
# 1 VNC         VN Pikachu   clan
# 2 King Allool xXx-Hadi-xXx clan

# %%
TF %>% mutate(power = c(100, -99))
# Out:
#   clan        player       power
# 1 VNC         VN Pikachu   100
# 2 King Allool xXx-Hadi-xXx -99

# %% [markdown]
# A case in point is `group_by()`. While you might think it has select semantics, it actually has mutate semantics. This is quite handy as it allows to group by a modified column:

# %%
group_by(starwars, height_binned = cut(height, 3))
# Out:
#     name                  height mass   hair_color    skin_color
# 1   Luke Skywalker        172      77.0 blond         fair
# 2   C-3PO                 167      75.0 NA            gold
# 3   R2-D2                  96      32.0 NA            white, blue
# 4   Darth Vader           202     136.0 none          white
# 5   Leia Organa           150      49.0 brown         light
# 6   Owen Lars             178     120.0 brown, grey   light
# 7   Beru Whitesun lars    165      75.0 brown         light
# 8   R5-D4                  97      32.0 NA            white, red
# 9   Biggs Darklighter     183      84.0 black         light
# 10  Obi-Wan Kenobi        182      77.0 auburn, white fair
# 11  Anakin Skywalker      188      84.0 blond         fair
# 12  Wilhuff Tarkin        180        NA auburn, grey  fair
# 13  Chewbacca             228     112.0 brown         unknown
# 14  Han Solo              180      80.0 brown         fair
# ...
