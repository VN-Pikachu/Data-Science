# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %% [markdown]
# <img src = './ggplot2_position_adjustment.png'/>

# %% [markdown]
# # Nudge points a fixed distance

# %% [markdown]
# `position_nudge()` is generally useful for adjusting the position of items on discrete scales by a small amount. Nudging is built in to `geom_text()` because it's so useful for moving labels a small distance from what they're labelling.

# %% [markdown]
# ```R
# position_nudge(x = 0, y = 0)
# ```

# %% [markdown]
# **Arguments**
# `x`, `y`
# Amount of vertical and horizontal distance to move.

# %%
df <- data.frame(
  x = c(1,3,2,5),
  y = c("a","c","d","c")
)
df
# Out:
#   x y
# 1 1 a
# 2 3 c
# 3 2 d
# 4 5 c

# %%
fig <- ggplot(df, aes(x, y)) + geom_point(size = 1, color = 'red')
fig + geom_text(aes(label = y))
# Out:
# plot without title

# %%
#increase x coordiate by 1 (in data coordinate) 
fig + geom_text(aes(label = y), position = position_nudge(x = 1))
# Out:
# plot without title

# %%
#descrease y coordiate by 0.5
fig + geom_text(aes(label = y), position = position_nudge(y = -0.5))
# Out:
# plot without title
