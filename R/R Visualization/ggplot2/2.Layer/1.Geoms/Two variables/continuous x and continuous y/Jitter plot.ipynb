# %%
setwd('C:/Users/dell/PycharmProjects/MachineLearning/Pandas/datasets')

# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %%
tips <- read.csv('./tips.csv')
head(tips)
# Out:
#   X total_bill tip  sex    smoker day time   size
# 1 0 16.99      1.01 Female No     Sun Dinner 2
# 2 1 10.34      1.66 Male   No     Sun Dinner 3
# 3 2 21.01      3.50 Male   No     Sun Dinner 3
# 4 3 23.68      3.31 Male   No     Sun Dinner 2
# 5 4 24.59      3.61 Female No     Sun Dinner 4
# 6 5 25.29      4.71 Male   No     Sun Dinner 4

# %% [markdown]
# <img src = '../ggplot2_twovariable.png'/>

# %% [markdown]
# # Jittered points

# %% [markdown]
# **`geom_jitter()`**: The jitter geom is a convenient shortcut for `geom_point(position = "jitter")`. It adds a small amount of random variation to the location of each point, and is a useful way of handling overplotting caused by discreteness in smaller datasets.

# %%
args(geom_jitter)
# Out:
# function (mapping = NULL, data = NULL, stat = "identity", position = "jitter",
#     ..., width = NULL, height = NULL, na.rm = FALSE, show.legend = NA,
#     inherit.aes = TRUE)
# NULL

# %% [markdown]
# **Arguments**
# `width`
# Amount of vertical and horizontal jitter. The jitter is added in both positive and negative directions, so the total spread is twice the value specified here.
#
# If omitted, defaults to 40% of the resolution of the data: this means the jitter values will occupy 80% of the implied bins. Categorical data is aligned on the integers, so a width or height of 0.5 will spread the data so it's not possible to see the distinction between the categories.
#
# `height`
# Amount of vertical and horizontal jitter. The jitter is added in both positive and negative directions, so the total spread is twice the value specified here.
#
# If omitted, defaults to 40% of the resolution of the data: this means the jitter values will occupy 80% of the implied bins. Categorical data is aligned on the integers, so a width or height of 0.5 will spread the data so it's not possible to see the distinction between the categories.

# %% [markdown]
# # Aesthetic

# %% [markdown]
# **`geom_point()`** understands the following aesthetics (required aesthetics are in bold):
#
# **x**
#
# **y**
#
# alpha
#
# colour: edge color
#
# fill: facecolor
#
# group
#
# shape: marker
#
# size
#
# stroke: linewidth

# %% [markdown]
# # Example

# %%
ggplot(tips, aes(day, total_bill, color = time)) +
geom_jitter(width = .05)
# Out:
# plot without title

# %%
#larger width
ggplot(tips, aes(day, total_bill, color = time)) +
geom_jitter(width = .3)
# Out:
# plot without title

# %%
#customization
ggplot(tips, aes(sex, total_bill, color = smoker)) +
geom_jitter(width = .1, #the variance of jitter horizontally,
            shape = 21,
            stroke = 1,  #set the linewidth of marker to 1,
            size = 2    #set marker size to 2
            )
# Out:
# plot without title
