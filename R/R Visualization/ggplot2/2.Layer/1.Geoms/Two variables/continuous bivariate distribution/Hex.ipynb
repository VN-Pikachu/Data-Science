# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %%
data(diamonds)
head(diamonds)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %% [markdown]
# # Hexagonal heatmap of 2d bin counts

# %% [markdown]
# **`geom_hex()`**, **`stat_bin_hex()`**: Divides the plane into regular hexagons, counts the number of cases in each hexagon, and then (by default) maps the number of cases to the hexagon fill.

# %%
args(geom_hex)
# Out:
# function (mapping = NULL, data = NULL, stat = "binhex", position = "identity",
#     ..., na.rm = FALSE, show.legend = NA, inherit.aes = TRUE)
# NULL

# %%
args(stat_bin_hex)
# Out:
# function (mapping = NULL, data = NULL, geom = "hex", position = "identity",
#     ..., bins = 30, binwidth = NULL, na.rm = FALSE, show.legend = NA,
#     inherit.aes = TRUE)
# NULL

# %% [markdown]
# `bins`
# numeric vector giving number of bins in both vertical and horizontal directions. Set to 30 by default.
#
# `binwidth`
# Numeric vector giving bin width in both vertical and horizontal directions. Overrides bins if both set.

# %% [markdown]
# # Aesthetic

# %% [markdown]
# **`geom_hex()`** understands the following aesthetics (required aesthetics are in bold):
#
# * **x**
#
# * **y**
#
# * alpha
#
# * colour
#
# * fill
#
# * group
#
# * linetype
#
# * size

# %% [markdown]
# # Example

# %%
ggplot(diamonds, aes(carat, price)) +
geom_hex()
# Out:
# plot without title

# %%
ggplot(diamonds, aes(carat, price)) +
geom_hex(bins = 50) #set 50 bins in both direction (horizontal and vertical)
# Out:
# plot without title

# %%
#set bin width in each direction
ggplot(diamonds, aes(carat, price)) +
geom_hex(binwidth = c(1, 100))
# Out:
# plot without title

# %% [markdown]
# **`stat_bin2d()`** for rectangle bin

# %%
ggplot(diamonds, aes(carat, price)) +
stat_bin2d()
# Out:
# plot without title
