# %%
library(ggplot2)
setwd('C:/Users/dell/PycharmProjects/MachineLearning/Pandas/datasets')
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %%
tips <- read.csv('./tips.csv')
head(tips)
# Out:
#   X total_bill tip  sex    smoker day time   size
# 1 0 16.99      1.01 Female No     Sun Dinner 2
# 2 1 10.34      1.66 Male   No     Sun Dinner 3
# 3 2 21.01      3.50 Male   No     Sun Dinner 3
# 4 3 23.68      3.31 Male   No     Sun Dinner 2
# 5 4 24.59      3.61 Female No     Sun Dinner 4
# 6 5 25.29      4.71 Male   No     Sun Dinner 4

# %% [markdown]
# # Violin plot

# %% [markdown]
# A violin plot is a compact display of a continuous distribution. It is a blend of **`geom_boxplot()`** and **`geom_density()`**: a violin plot is a mirrored density plot displayed in the same way as a boxplot.

# %% [markdown]
# ```R
# geom_violin(
#   mapping = NULL,
#   data = NULL,
#   stat = "ydensity",
#   position = "dodge",
#   ...,
#   draw_quantiles = NULL,
#   trim = TRUE,
#   scale = "area",
#   na.rm = FALSE,
#   orientation = NA,
#   show.legend = NA,
#   inherit.aes = TRUE
# )
#
# stat_ydensity(
#   mapping = NULL,
#   data = NULL,
#   geom = "violin",
#   position = "dodge",
#   ...,
#   bw = "nrd0",
#   adjust = 1,
#   kernel = "gaussian",
#   trim = TRUE,
#   scale = "area",
#   na.rm = FALSE,
#   orientation = NA,
#   show.legend = NA,
#   inherit.aes = TRUE
# )
# ```

# %% [markdown]
# **Arguments**
# `draw_quantiles`
# If not(NULL) (default), draw horizontal lines at the given quantiles of the density estimate.
#
# `trim`
# If TRUE (default), trim the tails of the violins to the range of the data. If FALSE, don't trim the tails.
#
# `scale`
# if "area" (default), all violins have the same area (before trimming the tails). If "count", areas are scaled proportionally to the number of observations. If "width", all violins have the same maximum width.
# bw
# The smoothing bandwidth to be used. If numeric, the standard deviation of the smoothing kernel. If character, a rule to choose the bandwidth, as listed in stats::bw.nrd().
#
# `adjust`
# A multiplicate bandwidth adjustment. This makes it possible to adjust the bandwidth while still using the a bandwidth estimator. For example, adjust = 1/2 means use half of the default bandwidth.
#
# `kernel`
# Kernel. See list of available kernels in density().

# %% [markdown]
# # Aesthetics

# %% [markdown]
# **`geom_violin()`** understands the following aesthetics (required aesthetics are in bold):
#
# **x**
#
# **y**
#
# alpha
#
# colour
#
# fill
#
# group
#
# linetype
#
# size
#
# weight

# %% [markdown]
# # Example

# %%
#Trim and not trim
g <- ggplot(tips, aes(sex, total_bill, fill = smoker)) 
g + geom_violin(trim = FALSE) + labs(title = 'trim')
g + geom_violin(trim = TRUE) + labs(title = 'Not trim')
# Out:
# plot without title
# plot without title

# %%
ggplot(tips, aes(sex, total_bill, color = smoker)) +
geom_violin(scale = 'width') #all violin have the same width
# Out:
# plot without title

# %%
#using smaller bandwidth, do not trim
ggplot(tips, aes(sex, total_bill, fill = smoker)) + 
geom_violin(adjust = 1/2, trim = FALSE)
# Out:
# plot without title

# %%
#customization
ggplot(tips, aes(sex, total_bill, fill = smoker)) +
geom_violin(size = 3,           #set the linewidth of violin to 3
            color = 'pink',     #set the edgecolor to pink
            linetype = 'dotted' #se the linestyle to ':'
           )
# Out:
# plot without title
