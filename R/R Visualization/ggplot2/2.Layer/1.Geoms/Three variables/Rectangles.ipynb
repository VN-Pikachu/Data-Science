# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %% [markdown]
# <b><a href = '../graphical primitives/primitives.ipynb'/>Notebook: Rectangle Primives</a></b>

# %% [markdown]
# <img src = './ggplot2_threevariable.png'/>

# %%
head(seals)
# Out:
#   lat  long   delta_long delta_lat
# 1 29.7 -172.8 -0.9150462 0.14347525
# 2 30.7 -172.8 -0.8670125 0.12838872
# 3 31.7 -172.8 -0.8189249 0.11323248
# 4 32.7 -172.8 -0.7707763 0.09802037
# 5 33.7 -172.8 -0.7225597 0.08276624
# 6 34.7 -172.8 -0.6742680 0.06748393

# %%
seals$z <- with(seals, sqrt(delta_long ^ 2 + delta_lat ^ 2))

l <- ggplot(seals, aes(long, lat))

# %%
l +  geom_raster(aes(fill = z))
# Out:
# plot without title

# %%
l + geom_tile(aes(fill = z))
# Out:
# plot without title

# %%
?geom_rect
