# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %%
setwd('C:/Users/dell/PycharmProjects/MachineLearning/Pandas/datasets')
getwd()
# Out:
# [1] "C:/Users/dell/PycharmProjects/MachineLearning/Pandas/datasets"

# %% [markdown]
# # Useful labeller functions

# %% [markdown]
# Labeller functions are in charge of formatting the strip labels of facet grids and wraps. Most of them accept a multi_line argument to control whether multiple factors (defined in formulae such as ~first + second) should be displayed on a single line separated with commas, or each on their own line.
# ```R
# label_value(labels, multi_line = TRUE)
#
# label_both(labels, multi_line = TRUE, sep = ": ")
#
# label_context(labels, multi_line = TRUE, sep = ": ")
#
# label_parsed(labels, multi_line = TRUE)
#
# label_wrap_gen(width = 25, multi_line = TRUE)
# ```
# **Arguments**
# `labels`
# Data frame of labels. Usually contains only one element, but faceting over multiple factors entails multiple label variables.
#
# `multi_line`
# Whether to display the labels of multiple factors on separate lines.
#
# `sep	`
# String separating variables and values.
#
# `width	`
# Maximum number of characters before wrapping the strip.
#
# Details

# %% [markdown]
# # Example

# %%
tips <- read.csv('./tips.csv')
head(tips)
# Out:
#   X total_bill tip  sex    smoker day time   size
# 1 0 16.99      1.01 Female No     Sun Dinner 2
# 2 1 10.34      1.66 Male   No     Sun Dinner 3
# 3 2 21.01      3.50 Male   No     Sun Dinner 3
# 4 3 23.68      3.31 Male   No     Sun Dinner 2
# 5 4 24.59      3.61 Female No     Sun Dinner 4
# 6 5 25.29      4.71 Male   No     Sun Dinner 4

# %%
plot <- ggplot(tips, aes(total_bill, tip)) + geom_point() + theme(strip.text.y = element_text(angle = 0))
plot
# Out:
# plot without title

# %%
 
plot + 
#label value only displays the value of a factor
facet_grid(day ~ ., labeller = label_value)
# Out:
# plot without title

# %%
#label_both displays both the variable name and the factor value.
plot + 
facet_grid(day ~ ., labeller = label_both)
# Out:
# plot without title

# %%
#label_context() is context-dependent
#Uses label_value() for single factor faceting and label_both() when multiple factors are involved. 

plot + 
facet_grid(day ~ sex + smoker, labeller = label_context)
# Out:
# plot without title

# %%
# Interpreting the labels as plotmath expressions
plot + 
facet_grid(cols = vars(factor(sex,labels = c('alpha', 'beta'))),
           labeller = label_parsed)
# Out:
# plot without title
