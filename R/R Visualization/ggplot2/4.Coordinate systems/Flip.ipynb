# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %% [markdown]
# <img src = './ggplot2_coordinate_systems.png'/>

# %% [markdown]
# Flip cartesian coordinates so that horizontal becomes vertical, and vertical, horizontal. This is primarily useful for converting geoms and statistics which display y conditional on x, to x conditional on y.

# %% [markdown]
# ```R
# coord_flip(xlim = NULL, ylim = NULL, expand = TRUE, clip = "on")
# ```

# %%
setwd('C:/Users/dell/PycharmProjects/MachineLearning/Pandas/datasets')

# %%
tips <- read.csv('./tips.csv')
head(tips)
# Out:
#   X total_bill tip  sex    smoker day time   size
# 1 0 16.99      1.01 Female No     Sun Dinner 2
# 2 1 10.34      1.66 Male   No     Sun Dinner 3
# 3 2 21.01      3.50 Male   No     Sun Dinner 3
# 4 3 23.68      3.31 Male   No     Sun Dinner 2
# 5 4 24.59      3.61 Female No     Sun Dinner 4
# 6 5 25.29      4.71 Male   No     Sun Dinner 4

# %%
# Very useful for creating boxplots, and other interval
# geoms in the horizontal instead of vertical position.
fig <- ggplot(tips, aes(day, total_bill)) + geom_boxplot()
fig
# Out:
# plot without title

# %%
#fip 
fig + coord_flip()
# Out:
# plot without title

# %%
# You can also use it to flip line and area plots:
x <- seq(-pi, pi, length.out = 100)
y <- sin(x)
func <- data.frame(x, y)

fig <- ggplot(func, aes(x, y)) + geom_line(color = 'red') + geom_hline(yintercept = 0) + geom_vline(xintercept = 0)
fig
# Out:
# plot without title

# %%
#flip
fig + coord_flip()
# Out:
# plot without title
