# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %% [markdown]
# <b style = 'color:red'>Read <a href = 'https://ggplot2.tidyverse.org/reference/coord_trans.html'>Documentation</a> for comprehensive example</b>

# %% [markdown]
# <img src = './ggplot2_coordinate_systems.png'/>

# %% [markdown]
# # Transformed Cartesian coordinate system

# %% [markdown]
# **coord_trans()** is different to scale transformations in that it occurs after statistical transformation and will affect the visual appearance of geoms - there is no guarantee that straight lines will continue to be straight.

# %% [markdown]
# ```R
# coord_trans(
#   x = "identity",
#   y = "identity",
#   xlim = NULL,
#   ylim = NULL,
#   limx = "DEPRECATED",
#   limy = "DEPRECATED",
#   clip = "on",
#   expand = TRUE
# )```

# %% [markdown]
# **Arguments**
# `x`, `y`
# Transformers for x and y axes or their names.

# %%
x <- seq(1, 1000, length.out = 50)
y <- x
func <- data.frame(x, y)

#transform y to sqrt(y)
ggplot(func, aes(x, sqrt(y))) + geom_line()
# Out:
# plot without title

# %%
#equivalently
ggplot(func, aes(x, y)) +
geom_line() +
coord_trans(y = 'sqrt')
# Out:
# plot without title
