# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %% [markdown]
# # Expand the plot limits, using data

# %% [markdown]
# Sometimes you may want to ensure limits include a single value, for all panels or all plots. This function is a thin wrapper around geom_blank() that makes it easy to add such values.

# %% [markdown]
# ```R
# expand_limits(...)
# ```

# %% [markdown]
# **Arguments**
# `...`
# named list of aesthetics specifying the value (or values) that should be included in each scale.

# %% [markdown]
# # Examples

# %%
p <- ggplot(mtcars, aes(mpg, wt)) + geom_point()
p + expand_limits(x = 0) #ensure x axis contains 0
# Out:
# plot without title

# %%
p + expand_limits(y = c(1, 9)) #ensure y axis contain values in range 1 -> 9
# Out:
# plot without title

# %%
p + expand_limits(x = 0, y = 0)  #ensure x axis contain 0, y axis contain zero
# Out:
# plot without title

# %%
ggplot(mtcars, aes(mpg, wt)) +
  geom_point(aes(colour = cyl)) +
  expand_limits(colour = seq(2, 10, by = 2))
# Out:
# plot without title
