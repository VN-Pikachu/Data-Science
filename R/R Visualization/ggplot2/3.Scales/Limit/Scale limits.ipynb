# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %% [markdown]
# # Set scale limits

# %% [markdown]
# This will remove data outside of limit

# %% [markdown]
# This is a shortcut for supplying the limits argument to the individual scales.
# **By default, any values outside the limits specified are replaced with NA**. Be warned that this will remove data outside the limits and this can produce unintended results.
# For changing x or y axis limits without dropping data observations, see `coord_cartesian()`.

# %% [markdown]
# ```R
# lims(...)
#
# xlim(...)
#
# ylim(...)
# ```

# %% [markdown]
# **Arguments**
# `...`
# For `xlim()` and `ylim()`: Two numeric values, specifying the left/lower limit and the right/upper limit of the scale. If the larger value is given first, the scale will be reversed. You can leave one value as NA if you want to compute the corresponding limit from the range of the data.
#
# For `lims()`: A name--value pair. The name must be an aesthetic, and the value must be either a length-2 numeric, a character, a factor, or a date/time. A numeric value will create a continuous scale. If the larger value comes first, the scale will be reversed. You can leave one value as NA if you want to compute the corresponding limit from the range of the data. A character or factor value will create a discrete scale. A date-time value will create a continuous date/time scale.

# %% [markdown]
# # Example

# %%
setwd('C:/Users/dell/PycharmProjects/MachineLearning/Pandas/datasets')
getwd()
# Out:
# [1] "C:/Users/dell/PycharmProjects/MachineLearning/Pandas/datasets"

# %%
tips <- read.csv('./tips.csv')
head(tips)
# Out:
#   X total_bill tip  sex    smoker day time   size
# 1 0 16.99      1.01 Female No     Sun Dinner 2
# 2 1 10.34      1.66 Male   No     Sun Dinner 3
# 3 2 21.01      3.50 Male   No     Sun Dinner 3
# 4 3 23.68      3.31 Male   No     Sun Dinner 2
# 5 4 24.59      3.61 Female No     Sun Dinner 4
# 6 5 25.29      4.71 Male   No     Sun Dinner 4

# %%
plot <- ggplot(tips, aes(total_bill, tip, color = day)) +  geom_point()
plot
# Out:
# plot without title

# %%
# Zoom into a specified area
plot + xlim(20, 40) + ylim(2.5, 5)
# Out:
# Warning message:
# "Removed 185 rows containing missing values (geom_point)."
# plot without title

# %%
# reverse scale
plot + xlim(40, 20)
# Out:
# Warning message:
# "Removed 157 rows containing missing values (geom_point)."
# plot without title

# %%
# with automatic lower limit
plot + xlim(NA, 20)
# Out:
# Warning message:
# "Removed 97 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# <hr>
