# %% [markdown]
# <b style = 'color:red'>MUST READ</b>
# Read **PART2.6: ENVIRONMENT** from this book *Hands-On Programming with R*:
# `file:///C:/Books/R/Hands-On%20Programming%20with%20R%20(%20PDFDrive%20).pdf`

# %% [markdown]
# <hr>

# %%
library(tidyverse)
library(devtools)

# Ignore these --------------------------
title <- 'Environment in R'
author <- 'VN Pikachu'
output <- 'document: html_document'

# %% [markdown]
# # Enviroment

# %% [markdown]
# Each object is saved inside of an *environment*,
# a list-like object that resembles a folder on your computer. Each environment is con‐
# nected to a parent environment, a higher-level environment, which creates a hierarchy
# of environments.

# %% [markdown]
# # Working with Environments

# %% [markdown]
# >Refer to any environments in your tree with **`as.environment
# `**

# %%
as.environment('package:stringr')
# Out:
# <environment: package:stringr>
# attr(,"name")
# [1] "package:stringr"
# attr(,"path")
# [1] "C:/Users/dell/Anaconda3/Lib/R/library/stringr"

# %% [markdown]
# >Three environments in your tree also come with their own accessor functions. These
# are the global environment (`R_GlobalEnv`), the base environment (`base`), and the empty
# environment (`R_EmptyEnv`). You can refer to them with:

# %%
globalenv()
# Out:
# <environment: R_GlobalEnv>

# %%
baseenv()
# Out:
# <environment: base>

# %%
emptyenv()
# Out:
# <environment: R_EmptyEnv>

# %% [markdown]
# >Next, you can look up an environment's parent with `parent.env`:

# %%
# what is the parent environment of R_GlobalEnv?
parent.env(globalenv())
# Out:
# <environment: package:devtools>
# attr(,"name")
# [1] "package:devtools"
# attr(,"path")
# [1] "C:/Users/dell/Anaconda3/Lib/R/library/devtools"

# %%
parent.env(baseenv())
# Out:
# <environment: R_EmptyEnv>

# %% [markdown]
# Notice that the empty environment is the only R environment without a parent:

# %%
parent.env(emptyenv())  %>% try()
# Out:
# Error in parent.env(emptyenv()): the empty environment has no parent
# Traceback:
#
# 1. parent.env(emptyenv()) %>% try()
# 2. eval(lhs, parent, parent)
# 3. eval(lhs, parent, parent)
# 4. parent.env(emptyenv())

# %% [markdown]
# >You can view an objects saved in an environment with `ls` or `ls.str`

# %% [markdown]
# the global environment has some familiar faces. It is where
# R has saved all of the objects that you’ve created so far.

# %%
ls(globalenv())
# Out:
# [1] "author" "output" "title"

# %%
ls.str(globalenv())
# Out:
# author :  chr "VN Pikachu"
# output :  chr "document: html_document"
# title :  chr "Environment in R"

# %% [markdown]
# As expected, `emptyenv()` is empty

# %%
ls(emptyenv())
# Out:
# character(0)

# %%
ls(baseenv())
# Out:
#    [1] "-"                                  "-.Date"
#    [3] "-.POSIXt"                           "!"
#    [5] "!.hexmode"                          "!.octmode"
#    [7] "!="                                 "$"
#    [9] "$.DLLInfo"                          "$.package_version"
#   [11] "$<-"                                "$<-.data.frame"
#   [13] "%%"                                 "%*%"
#   [15] "%/%"                                "%in%"
#   [17] "%o%"                                "%x%"
#   [19] "&"                                  "&&"
#   [21] "&.hexmode"                          "&.octmode"
#   [23] "("                                  "*"
#   [25] "*.difftime"                         "/"
#   [27] "/.difftime"                         ":"
#   [29] "::"                                 ":::"
#   [31] "@"                                  "@<-"
#   [33] "["                                  "[.AsIs"
#   [35] "[.data.frame"                       "[.Date"
#   [37] "[.difftime"                         "[.Dlist"
#   [39] "[.DLLInfoList"                      "[.factor"
#   [41] "[.hexmode"                          "[.listof"
#   [43] "[.noquote"                          "[.numeric_version"
#   [45] "[.octmode"                          "[.POSIXct"
#   [47] "[.POSIXlt"                          "[.simple.list"
#   [49] "[.table"                            "[.warnings"
#   [51] "[["                                 "[[.data.frame"
#   [53] "[[.Date"                            "[[.factor"
#   [55] "[[.numeric_version"                 "[[.POSIXct"
#   [57] "[[.POSIXlt"                         "[[<-"
#   [59] "[[<-.data.frame"                    "[[<-.factor"
#   [61] "[[<-.numeric_version"               "[[<-.POSIXlt"
#   [63] "[<-"                                "[<-.data.frame"
#   [65] "[<-.Date"                           "[<-.factor"
#   [67] "[<-.numeric_version"                "[<-.POSIXct"
#   [69] "[<-.POSIXlt"                        "^"
#   [71] "{"                                  "|"
#   [73] "|.hexmode"                          "|.octmode"
#   [75] "||"                                 "~"
#   [77] "+"                                  "+.Date"
#   [79] "+.POSIXt"                           "<"
#   [81] "<-"                                 "<<-"
#   [83] "<="                                 "="
#   [85] "=="                                 ">"
#   [87] ">="                                 "abbreviate"
#   [89] "abs"                                "acos"
#   [91] "acosh"                              "addNA"
#   [93] "addTaskCallback"                    "agrep"
#   [95] "agrepl"                             "alist"
#   [97] "all"                                "all.equal"
#   [99] "all.equal.character"                "all.equal.default"
#  [101] "all.equal.environment"              "all.equal.envRefClass"
#  [103] "all.equal.factor"                   "all.equal.formula"
#  [105] "all.equal.language"                 "all.equal.list"
#  [107] "all.equal.numeric"                  "all.equal.POSIXt"
#  [109] "all.equal.raw"                      "all.names"
#  [111] "all.vars"                           "allowInterrupts"
#  [113] "any"                                "anyDuplicated"
#  [115] "anyDuplicated.array"                "anyDuplicated.data.frame"
#  [117] "anyDuplicated.default"              "anyDuplicated.matrix"
#  [119] "anyNA"                              "anyNA.numeric_version"
#  [121] "anyNA.POSIXlt"                      "aperm"
#  [123] "aperm.default"                      "aperm.table"
#  [125] "append"                             "apply"
#  [127] "Arg"                                "args"
#  [129] "array"                              "arrayInd"
#  [131] "as.array"                           "as.array.default"
#  [133] "as.call"                            "as.character"
#  [135] "as.character.condition"             "as.character.Date"
#  [137] "as.character.default"               "as.character.error"
#  [139] "as.character.factor"                "as.character.hexmode"
#  [141] "as.character.numeric_version"       "as.character.octmode"
#  [143] "as.character.POSIXt"                "as.character.srcref"
#  [145] "as.complex"                         "as.data.frame"
#  [147] "as.data.frame.array"                "as.data.frame.AsIs"
#  [149] "as.data.frame.character"            "as.data.frame.complex"
#  [151] "as.data.frame.data.frame"           "as.data.frame.Date"
#  [153] "as.data.frame.default"              "as.data.frame.difftime"
#  [155] "as.data.frame.factor"               "as.data.frame.integer"
#  [157] "as.data.frame.list"                 "as.data.frame.logical"
#  [159] "as.data.frame.matrix"               "as.data.frame.model.matrix"
#  [161] "as.data.frame.noquote"              "as.data.frame.numeric"
#  [163] "as.data.frame.numeric_version"      "as.data.frame.ordered"
#  [165] "as.data.frame.POSIXct"              "as.data.frame.POSIXlt"
#  [167] "as.data.frame.raw"                  "as.data.frame.table"
#  [169] "as.data.frame.ts"                   "as.data.frame.vector"
#  [171] "as.Date"                            "as.Date.character"
#  [173] "as.Date.default"                    "as.Date.factor"
#  [175] "as.Date.numeric"                    "as.Date.POSIXct"
#  [177] "as.Date.POSIXlt"                    "as.difftime"
#  [179] "as.double"                          "as.double.difftime"
#  [181] "as.double.POSIXlt"                  "as.environment"
#  [183] "as.expression"                      "as.expression.default"
#  [185] "as.factor"                          "as.function"
#  [187] "as.function.default"                "as.hexmode"
#  [189] "as.integer"                         "as.list"
#  [191] "as.list.data.frame"                 "as.list.Date"
#  [193] "as.list.default"                    "as.list.environment"
#  [195] "as.list.factor"                     "as.list.function"
#  [197] "as.list.numeric_version"            "as.list.POSIXct"
#  [199] "as.list.POSIXlt"                    "as.logical"
#  [201] "as.logical.factor"                  "as.matrix"
#  [203] "as.matrix.data.frame"               "as.matrix.default"
#  [205] "as.matrix.noquote"                  "as.matrix.POSIXlt"
#  [207] "as.name"                            "as.null"
#  [209] "as.null.default"                    "as.numeric"
#  [211] "as.numeric_version"                 "as.octmode"
#  [213] "as.ordered"                         "as.package_version"
#  [215] "as.pairlist"                        "as.POSIXct"
#  [217] "as.POSIXct.Date"                    "as.POSIXct.default"
#  [219] "as.POSIXct.numeric"                 "as.POSIXct.POSIXlt"
#  [221] "as.POSIXlt"                         "as.POSIXlt.character"
#  [223] "as.POSIXlt.Date"                    "as.POSIXlt.default"
#  [225] "as.POSIXlt.factor"                  "as.POSIXlt.numeric"
#  [227] "as.POSIXlt.POSIXct"                 "as.qr"
#  [229] "as.raw"                             "as.single"
#  [231] "as.single.default"                  "as.symbol"
#  [233] "as.table"                           "as.table.default"
#  [235] "as.vector"                          "as.vector.factor"
#  [237] "asin"                               "asinh"
#  [239] "asNamespace"                        "asplit"
#  [241] "asS3"                               "asS4"
#  [243] "assign"                             "atan"
#  [245] "atan2"                              "atanh"
#  [247] "attach"                             "attachNamespace"
#  [249] "attr"                               "attr.all.equal"
#  [251] "attr<-"                             "attributes"
#  [253] "attributes<-"                       "autoload"
#  [255] "autoloader"                         "backsolve"
#  [257] "baseenv"                            "basename"
#  [259] "besselI"                            "besselJ"
#  [261] "besselK"                            "besselY"
#  [263] "beta"                               "bindingIsActive"
#  [265] "bindingIsLocked"                    "bindtextdomain"
#  [267] "bitwAnd"                            "bitwNot"
#  [269] "bitwOr"                             "bitwShiftL"
#  [271] "bitwShiftR"                         "bitwXor"
#  [273] "body"                               "body<-"
#  [275] "bquote"                             "break"
#  [277] "browser"                            "browserCondition"
#  [279] "browserSetDebug"                    "browserText"
#  [281] "builtins"                           "by"
#  [283] "by.data.frame"                      "by.default"
#  [285] "bzfile"                             "c"
#  [287] "c.Date"                             "c.difftime"
#  [289] "c.noquote"                          "c.numeric_version"
#  [291] "c.POSIXct"                          "c.POSIXlt"
#  [293] "c.warnings"                         "call"
#  [295] "callCC"                             "capabilities"
#  [297] "casefold"                           "cat"
#  [299] "cbind"                              "cbind.data.frame"
#  [301] "ceiling"                            "char.expand"
#  [303] "character"                          "charmatch"
#  [305] "charToRaw"                          "chartr"
#  [307] "check_tzones"                       "chkDots"
#  [309] "chol"                               "chol.default"
#  [311] "chol2inv"                           "choose"
#  [313] "class"                              "class<-"
#  [315] "clearPushBack"                      "close"
#  [317] "close.connection"                   "close.srcfile"
#  [319] "close.srcfilealias"                 "closeAllConnections"
#  [321] "col"                                "colMeans"
#  [323] "colnames"                           "colnames<-"
#  [325] "colSums"                            "commandArgs"
#  [327] "comment"                            "comment<-"
#  [329] "complex"                            "computeRestarts"
#  [331] "conditionCall"                      "conditionCall.condition"
#  [333] "conditionMessage"                   "conditionMessage.condition"
#  [335] "conflictRules"                      "conflicts"
#  [337] "Conj"                               "contributors"
#  [339] "cos"                                "cosh"
#  [341] "cospi"                              "crossprod"
#  [343] "Cstack_info"                        "cummax"
#  [345] "cummin"                             "cumprod"
#  [347] "cumsum"                             "curlGetHeaders"
#  [349] "cut"                                "cut.Date"
#  [351] "cut.default"                        "cut.POSIXt"
#  [353] "data.class"                         "data.frame"
#  [355] "data.matrix"                        "date"
#  [357] "debug"                              "debuggingState"
#  [359] "debugonce"                          "default.stringsAsFactors"
#  [361] "delayedAssign"                      "deparse"
#  [363] "det"                                "detach"
#  [365] "determinant"                        "determinant.matrix"
#  [367] "dget"                               "diag"
#  [369] "diag<-"                             "diff"
#  [371] "diff.Date"                          "diff.default"
#  [373] "diff.difftime"                      "diff.POSIXt"
#  [375] "difftime"                           "digamma"
#  [377] "dim"                                "dim.data.frame"
#  [379] "dim<-"                              "dimnames"
#  [381] "dimnames.data.frame"                "dimnames<-"
#  [383] "dimnames<-.data.frame"              "dir"
#  [385] "dir.create"                         "dir.exists"
#  [387] "dirname"                            "do.call"
#  [389] "dontCheck"                          "double"
#  [391] "dput"                               "dQuote"
#  [393] "drop"                               "droplevels"
#  [395] "droplevels.data.frame"              "droplevels.factor"
#  [397] "dump"                               "duplicated"
#  [399] "duplicated.array"                   "duplicated.data.frame"
#  [401] "duplicated.default"                 "duplicated.matrix"
#  [403] "duplicated.numeric_version"         "duplicated.POSIXlt"
#  [405] "duplicated.warnings"                "dyn.load"
#  [407] "dyn.unload"                         "dynGet"
#  [409] "eapply"                             "eigen"
#  [411] "emptyenv"                           "enc2native"
#  [413] "enc2utf8"                           "encodeString"
#  [415] "Encoding"                           "Encoding<-"
#  [417] "endsWith"                           "enquote"
#  [419] "env.profile"                        "environment"
#  [421] "environment<-"                      "environmentIsLocked"
#  [423] "environmentName"                    "errorCondition"
#  [425] "eval"                               "eval.parent"
#  [427] "evalq"                              "exists"
#  [429] "exp"                                "expand.grid"
#  [431] "expm1"                              "expression"
#  [433] "extSoftVersion"                     "F"
#  [435] "factor"                             "factorial"
#  [437] "fifo"                               "file"
#  [439] "file.access"                        "file.append"
#  [441] "file.choose"                        "file.copy"
#  [443] "file.create"                        "file.exists"
#  [445] "file.info"                          "file.link"
#  [447] "file.mode"                          "file.mtime"
#  [449] "file.path"                          "file.remove"
#  [451] "file.rename"                        "file.show"
#  [453] "file.size"                          "file.symlink"
#  [455] "Filter"                             "Find"
#  [457] "find.package"                       "findInterval"
#  [459] "findPackageEnv"                     "findRestart"
#  [461] "floor"                              "flush"
#  [463] "flush.connection"                   "for"
#  [465] "force"                              "forceAndCall"
#  [467] "formals"                            "formals<-"
#  [469] "format"                             "format.AsIs"
#  [471] "format.data.frame"                  "format.Date"
#  [473] "format.default"                     "format.difftime"
#  [475] "format.factor"                      "format.hexmode"
#  [477] "format.info"                        "format.libraryIQR"
#  [479] "format.numeric_version"             "format.octmode"
#  [481] "format.packageInfo"                 "format.POSIXct"
#  [483] "format.POSIXlt"                     "format.pval"
#  [485] "format.summaryDefault"              "formatC"
#  [487] "formatDL"                           "forwardsolve"
#  [489] "function"                           "gamma"
#  [491] "gc"                                 "gc.time"
#  [493] "gcinfo"                             "gctorture"
#  [495] "gctorture2"                         "get"
#  [497] "get0"                               "getAllConnections"
#  [499] "getCallingDLL"                      "getCallingDLLe"
#  [501] "getConnection"                      "getDLLRegisteredRoutines"
#  [503] "getDLLRegisteredRoutines.character" "getDLLRegisteredRoutines.DLLInfo"
#  [505] "getElement"                         "geterrmessage"
#  [507] "getExportedValue"                   "getHook"
#  [509] "getLoadedDLLs"                      "getNamespace"
#  [511] "getNamespaceExports"                "getNamespaceImports"
#  [513] "getNamespaceInfo"                   "getNamespaceName"
#  [515] "getNamespaceUsers"                  "getNamespaceVersion"
#  [517] "getNativeSymbolInfo"                "getOption"
#  [519] "getRversion"                        "getSrcLines"
#  [521] "getTaskCallbackNames"               "gettext"
#  [523] "gettextf"                           "getwd"
#  [525] "gl"                                 "globalenv"
#  [527] "gregexpr"                           "grep"
#  [529] "grepl"                              "grepRaw"
#  [531] "grouping"                           "gsub"
#  [533] "gzcon"                              "gzfile"
#  [535] "I"                                  "iconv"
#  [537] "iconvlist"                          "icuGetCollate"
#  [539] "icuSetCollate"                      "identical"
#  [541] "identity"                           "if"
#  [543] "ifelse"                             "Im"
#  [545] "importIntoEnv"                      "inherits"
#  [547] "integer"                            "interaction"
#  [549] "interactive"                        "intersect"
#  [551] "intToBits"                          "intToUtf8"
#  [553] "inverse.rle"                        "invisible"
#  [555] "invokeRestart"                      "invokeRestartInteractively"
#  [557] "is.array"                           "is.atomic"
#  [559] "is.call"                            "is.character"
#  [561] "is.complex"                         "is.data.frame"
#  [563] "is.double"                          "is.element"
#  [565] "is.environment"                     "is.expression"
#  [567] "is.factor"                          "is.finite"
#  [569] "is.function"                        "is.infinite"
#  [571] "is.integer"                         "is.language"
#  [573] "is.list"                            "is.loaded"
#  [575] "is.logical"                         "is.matrix"
#  [577] "is.na"                              "is.na.data.frame"
#  [579] "is.na.numeric_version"              "is.na.POSIXlt"
#  [581] "is.na<-"                            "is.na<-.default"
#  [583] "is.na<-.factor"                     "is.na<-.numeric_version"
#  [585] "is.name"                            "is.nan"
#  [587] "is.null"                            "is.numeric"
#  [589] "is.numeric.Date"                    "is.numeric.difftime"
#  [591] "is.numeric.POSIXt"                  "is.numeric_version"
#  [593] "is.object"                          "is.ordered"
#  [595] "is.package_version"                 "is.pairlist"
#  [597] "is.primitive"                       "is.qr"
#  [599] "is.R"                               "is.raw"
#  [601] "is.recursive"                       "is.single"
#  [603] "is.symbol"                          "is.table"
#  [605] "is.unsorted"                        "is.vector"
#  [607] "isatty"                             "isBaseNamespace"
#  [609] "isdebugged"                         "isFALSE"
#  [611] "isIncomplete"                       "isNamespace"
#  [613] "isNamespaceLoaded"                  "ISOdate"
#  [615] "ISOdatetime"                        "isOpen"
#  [617] "isRestart"                          "isS4"
#  [619] "isSeekable"                         "isSymmetric"
#  [621] "isSymmetric.matrix"                 "isTRUE"
#  [623] "jitter"                             "julian"
#  [625] "julian.Date"                        "julian.POSIXt"
#  [627] "kappa"                              "kappa.default"
#  [629] "kappa.lm"                           "kappa.qr"
#  [631] "kronecker"                          "l10n_info"
#  [633] "La.svd"                             "La_library"
#  [635] "La_version"                         "labels"
#  [637] "labels.default"                     "lapply"
#  [639] "lazyLoad"                           "lazyLoadDBexec"
#  [641] "lazyLoadDBfetch"                    "lbeta"
#  [643] "lchoose"                            "length"
#  [645] "length.POSIXlt"                     "length<-"
#  [647] "length<-.Date"                      "length<-.difftime"
#  [649] "length<-.factor"                    "length<-.POSIXct"
#  [651] "length<-.POSIXlt"                   "lengths"
#  [653] "letters"                            "LETTERS"
#  [655] "levels"                             "levels.default"
#  [657] "levels<-"                           "levels<-.factor"
#  [659] "lfactorial"                         "lgamma"
#  [661] "libcurlVersion"                     "library"
#  [663] "library.dynam"                      "library.dynam.unload"
#  [665] "licence"                            "license"
#  [667] "list"                               "list.dirs"
#  [669] "list.files"                         "list2env"
#  [671] "load"                               "loadedNamespaces"
#  [673] "loadingNamespaceInfo"               "loadNamespace"
#  [675] "local"                              "lockBinding"
#  [677] "lockEnvironment"                    "log"
#  [679] "log10"                              "log1p"
#  [681] "log2"                               "logb"
#  [683] "logical"                            "lower.tri"
#  [685] "ls"                                 "make.names"
#  [687] "make.unique"                        "makeActiveBinding"
#  [689] "Map"                                "mapply"
#  [691] "margin.table"                       "mat.or.vec"
#  [693] "match"                              "match.arg"
#  [695] "match.call"                         "match.fun"
#  [697] "Math.data.frame"                    "Math.Date"
#  [699] "Math.difftime"                      "Math.factor"
#  [701] "Math.POSIXt"                        "matrix"
#  [703] "max"                                "max.col"
#  [705] "mean"                               "mean.Date"
#  [707] "mean.default"                       "mean.difftime"
#  [709] "mean.POSIXct"                       "mean.POSIXlt"
#  [711] "mem.limits"                         "mem.maxNSize"
#  [713] "mem.maxVSize"                       "memCompress"
#  [715] "memDecompress"                      "memory.profile"
#  [717] "merge"                              "merge.data.frame"
#  [719] "merge.default"                      "message"
#  [721] "mget"                               "min"
#  [723] "missing"                            "Mod"
#  [725] "mode"                               "mode<-"
#  [727] "month.abb"                          "month.name"
#  [729] "months"                             "months.Date"
#  [731] "months.POSIXt"                      "mostattributes<-"
#  [733] "names"                              "names.POSIXlt"
#  [735] "names<-"                            "names<-.POSIXlt"
#  [737] "namespaceExport"                    "namespaceImport"
#  [739] "namespaceImportClasses"             "namespaceImportFrom"
#  [741] "namespaceImportMethods"             "nargs"
#  [743] "nchar"                              "ncol"
#  [745] "NCOL"                               "Negate"
#  [747] "new.env"                            "next"
#  [749] "NextMethod"                         "ngettext"
#  [751] "nlevels"                            "noquote"
#  [753] "norm"                               "normalizePath"
#  [755] "nrow"                               "NROW"
#  [757] "nullfile"                           "numeric"
#  [759] "numeric_version"                    "nzchar"
#  [761] "objects"                            "oldClass"
#  [763] "oldClass<-"                         "OlsonNames"
#  [765] "on.exit"                            "open"
#  [767] "open.connection"                    "open.srcfile"
#  [769] "open.srcfilealias"                  "open.srcfilecopy"
#  [771] "Ops.data.frame"                     "Ops.Date"
#  [773] "Ops.difftime"                       "Ops.factor"
#  [775] "Ops.numeric_version"                "Ops.ordered"
#  [777] "Ops.POSIXt"                         "options"
#  [779] "order"                              "ordered"
#  [781] "outer"                              "package_version"
#  [783] "packageEvent"                       "packageHasNamespace"
#  [785] "packageNotFoundError"               "packageStartupMessage"
#  [787] "packBits"                           "pairlist"
#  [789] "parent.env"                         "parent.env<-"
#  [791] "parent.frame"                       "parse"
#  [793] "parseNamespaceFile"                 "paste"
#  [795] "paste0"                             "path.expand"
#  [797] "path.package"                       "pcre_config"
#  [799] "pi"                                 "pipe"
#  [801] "pmatch"                             "pmax"
#  [803] "pmax.int"                           "pmin"
#  [805] "pmin.int"                           "polyroot"
#  [807] "pos.to.env"                         "Position"
#  [809] "pretty"                             "pretty.default"
#  [811] "prettyNum"                          "print"
#  [813] "print.AsIs"                         "print.by"
#  [815] "print.condition"                    "print.connection"
#  [817] "print.data.frame"                   "print.Date"
#  [819] "print.default"                      "print.difftime"
#  [821] "print.Dlist"                        "print.DLLInfo"
#  [823] "print.DLLInfoList"                  "print.DLLRegisteredRoutines"
#  [825] "print.eigen"                        "print.factor"
#  [827] "print.function"                     "print.hexmode"
#  [829] "print.libraryIQR"                   "print.listof"
#  [831] "print.NativeRoutineList"            "print.noquote"
#  [833] "print.numeric_version"              "print.octmode"
#  [835] "print.packageInfo"                  "print.POSIXct"
#  [837] "print.POSIXlt"                      "print.proc_time"
#  [839] "print.restart"                      "print.rle"
#  [841] "print.simple.list"                  "print.srcfile"
#  [843] "print.srcref"                       "print.summary.table"
#  [845] "print.summary.warnings"             "print.summaryDefault"
#  [847] "print.table"                        "print.warnings"
#  [849] "prmatrix"                           "proc.time"
#  [851] "prod"                               "prop.table"
#  [853] "provideDimnames"                    "psigamma"
#  [855] "pushBack"                           "pushBackLength"
#  [857] "q"                                  "qr"
#  [859] "qr.coef"                            "qr.default"
#  [861] "qr.fitted"                          "qr.Q"
#  [863] "qr.qty"                             "qr.qy"
#  [865] "qr.R"                               "qr.resid"
#  [867] "qr.solve"                           "qr.X"
#  [869] "quarters"                           "quarters.Date"
#  [871] "quarters.POSIXt"                    "quit"
#  [873] "quote"                              "R.home"
#  [875] "R.version"                          "R.Version"
#  [877] "R.version.string"                   "R_system_version"
#  [879] "range"                              "range.default"
#  [881] "rank"                               "rapply"
#  [883] "raw"                                "rawConnection"
#  [885] "rawConnectionValue"                 "rawShift"
#  [887] "rawToBits"                          "rawToChar"
#  [889] "rbind"                              "rbind.data.frame"
#  [891] "rcond"                              "Re"
#  [893] "read.dcf"                           "readBin"
#  [895] "readChar"                           "readline"
#  [897] "readLines"                          "readRDS"
#  [899] "readRenviron"                       "Recall"
#  [901] "Reduce"                             "reg.finalizer"
#  [903] "regexec"                            "regexpr"
#  [905] "registerS3method"                   "registerS3methods"
#  [907] "regmatches"                         "regmatches<-"
#  [909] "remove"                             "removeTaskCallback"
#  [911] "rep"                                "rep.Date"
#  [913] "rep.factor"                         "rep.int"
#  [915] "rep.numeric_version"                "rep.POSIXct"
#  [917] "rep.POSIXlt"                        "rep_len"
#  [919] "repeat"                             "replace"
#  [921] "replicate"                          "require"
#  [923] "requireNamespace"                   "restartDescription"
#  [925] "restartFormals"                     "retracemem"
#  [927] "return"                             "returnValue"
#  [929] "rev"                                "rev.default"
#  [931] "rle"                                "rm"
#  [933] "RNGkind"                            "RNGversion"
#  [935] "round"                              "round.Date"
#  [937] "round.POSIXt"                       "row"
#  [939] "row.names"                          "row.names.data.frame"
#  [941] "row.names.default"                  "row.names<-"
#  [943] "row.names<-.data.frame"             "row.names<-.default"
#  [945] "rowMeans"                           "rownames"
#  [947] "rownames<-"                         "rowsum"
#  [949] "rowsum.data.frame"                  "rowsum.default"
#  [951] "rowSums"                            "sample"
#  [953] "sample.int"                         "sapply"
#  [955] "save"                               "save.image"
#  [957] "saveRDS"                            "scale"
#  [959] "scale.default"                      "scan"
#  [961] "search"                             "searchpaths"
#  [963] "seek"                               "seek.connection"
#  [965] "seq"                                "seq.Date"
#  [967] "seq.default"                        "seq.int"
#  [969] "seq.POSIXt"                         "seq_along"
#  [971] "seq_len"                            "sequence"
#  [973] "serialize"                          "set.seed"
#  [975] "setdiff"                            "setequal"
#  [977] "setHook"                            "setNamespaceInfo"
#  [979] "setSessionTimeLimit"                "setTimeLimit"
#  [981] "setwd"                              "shell"
#  [983] "shell.exec"                         "showConnections"
#  [985] "shQuote"                            "sign"
#  [987] "signalCondition"                    "signif"
#  [989] "simpleCondition"                    "simpleError"
#  [991] "simpleMessage"                      "simpleWarning"
#  [993] "simplify2array"                     "sin"
#  [995] "single"                             "sinh"
#  [997] "sink"                               "sink.number"
#  [999] "sinpi"                              "slice.index"
# [1001] "socketConnection"                   "socketSelect"
# [1003] "solve"                              "solve.default"
# [1005] "solve.qr"                           "sort"
# [1007] "sort.default"                       "sort.int"
# [1009] "sort.list"                          "sort.POSIXlt"
# [1011] "source"                             "split"
# [1013] "split.data.frame"                   "split.Date"
# [1015] "split.default"                      "split.POSIXct"
# [1017] "split<-"                            "split<-.data.frame"
# [1019] "split<-.default"                    "sprintf"
# [1021] "sqrt"                               "sQuote"
# [1023] "srcfile"                            "srcfilealias"
# [1025] "srcfilecopy"                        "srcref"
# [1027] "standardGeneric"                    "startsWith"
# [1029] "stderr"                             "stdin"
# [1031] "stdout"                             "stop"
# [1033] "stopifnot"                          "storage.mode"
# [1035] "storage.mode<-"                     "str2expression"
# [1037] "str2lang"                           "strftime"
# [1039] "strptime"                           "strrep"
# [1041] "strsplit"                           "strtoi"
# [1043] "strtrim"                            "structure"
# [1045] "strwrap"                            "sub"
# [1047] "subset"                             "subset.data.frame"
# [1049] "subset.default"                     "subset.matrix"
# [1051] "substitute"                         "substr"
# [1053] "substr<-"                           "substring"
# [1055] "substring<-"                        "sum"
# [1057] "summary"                            "summary.connection"
# [1059] "summary.data.frame"                 "Summary.data.frame"
# [1061] "summary.Date"                       "Summary.Date"
# [1063] "summary.default"                    "Summary.difftime"
# [1065] "summary.factor"                     "Summary.factor"
# [1067] "summary.matrix"                     "Summary.numeric_version"
# [1069] "Summary.ordered"                    "summary.POSIXct"
# [1071] "Summary.POSIXct"                    "summary.POSIXlt"
# [1073] "Summary.POSIXlt"                    "summary.proc_time"
# [1075] "summary.srcfile"                    "summary.srcref"
# [1077] "summary.table"                      "summary.warnings"
# [1079] "suppressMessages"                   "suppressPackageStartupMessages"
# [1081] "suppressWarnings"                   "suspendInterrupts"
# [1083] "svd"                                "sweep"
# [1085] "switch"                             "sys.call"
# [1087] "sys.calls"                          "Sys.chmod"
# [1089] "Sys.Date"                           "sys.frame"
# [1091] "sys.frames"                         "sys.function"
# [1093] "Sys.getenv"                         "Sys.getlocale"
# [1095] "Sys.getpid"                         "Sys.glob"
# [1097] "Sys.info"                           "Sys.junction"
# [1099] "sys.load.image"                     "Sys.localeconv"
# [1101] "sys.nframe"                         "sys.on.exit"
# [1103] "sys.parent"                         "sys.parents"
# [1105] "Sys.readlink"                       "sys.save.image"
# [1107] "Sys.setenv"                         "Sys.setFileTime"
# [1109] "Sys.setlocale"                      "Sys.sleep"
# [1111] "sys.source"                         "sys.status"
# [1113] "Sys.time"                           "Sys.timezone"
# [1115] "Sys.umask"                          "Sys.unsetenv"
# [1117] "Sys.which"                          "system"
# [1119] "system.file"                        "system.time"
# [1121] "system2"                            "t"
# [1123] "T"                                  "t.data.frame"
# [1125] "t.default"                          "table"
# [1127] "tabulate"                           "tan"
# [1129] "tanh"                               "tanpi"
# [1131] "tapply"                             "taskCallbackManager"
# [1133] "tcrossprod"                         "tempdir"
# [1135] "tempfile"                           "textConnection"
# [1137] "textConnectionValue"                "tolower"
# [1139] "topenv"                             "toString"
# [1141] "toString.default"                   "toupper"
# [1143] "trace"                              "traceback"
# [1145] "tracemem"                           "tracingState"
# [1147] "transform"                          "transform.data.frame"
# [1149] "transform.default"                  "trigamma"
# [1151] "trimws"                             "trunc"
# [1153] "trunc.Date"                         "trunc.POSIXt"
# [1155] "truncate"                           "truncate.connection"
# [1157] "try"                                "tryCatch"
# [1159] "typeof"                             "unclass"
# [1161] "undebug"                            "union"
# [1163] "unique"                             "unique.array"
# [1165] "unique.data.frame"                  "unique.default"
# [1167] "unique.matrix"                      "unique.numeric_version"
# [1169] "unique.POSIXlt"                     "unique.warnings"
# [1171] "units"                              "units.difftime"
# [1173] "units<-"                            "units<-.difftime"
# [1175] "unix.time"                          "unlink"
# [1177] "unlist"                             "unloadNamespace"
# [1179] "unlockBinding"                      "unname"
# [1181] "unserialize"                        "unsplit"
# [1183] "untrace"                            "untracemem"
# [1185] "unz"                                "upper.tri"
# [1187] "url"                                "UseMethod"
# [1189] "utf8ToInt"                          "validEnc"
# [1191] "validUTF8"                          "vapply"
# [1193] "vector"                             "Vectorize"
# [1195] "version"                            "warning"
# [1197] "warningCondition"                   "warnings"
# [1199] "weekdays"                           "weekdays.Date"
# [1201] "weekdays.POSIXt"                    "which"
# [1203] "which.max"                          "which.min"
# [1205] "while"                              "with"
# [1207] "with.default"                       "withAutoprint"
# [1209] "withCallingHandlers"                "within"
# [1211] "within.data.frame"                  "within.list"
# [1213] "withRestarts"                       "withVisible"
# [1215] "write"                              "write.dcf"
# [1217] "writeBin"                           "writeChar"
# [1219] "writeLines"                         "xor"
# [1221] "xpdrows.data.frame"                 "xtfrm"
# [1223] "xtfrm.AsIs"                         "xtfrm.Date"
# [1225] "xtfrm.default"                      "xtfrm.difftime"
# [1227] "xtfrm.factor"                       "xtfrm.numeric_version"
# [1229] "xtfrm.POSIXct"                      "xtfrm.POSIXlt"
# [1231] "xzfile"                             "zapsmall"

# %% [markdown]
# >You can use R’s `$` syntax to access an object in a specific environment.

# %%
ls.str(globalenv())
# Out:
# author :  chr "VN Pikachu"
# output :  chr "document: html_document"
# title :  chr "Environment in R"

# %%
globalenv()$author

globalenv()$output

globalenv()$title
# Out:
# [1] "VN Pikachu"
# [1] "document: html_document"
# [1] "Environment in R"

# %% [markdown]
# >And you can use the `assign` function to save an object into a particular environment. It will overwrite an object if it already exists.

# %%
# create a new object in the global environment:

assign('options', 'website', envir = globalenv())

# %%
ls(globalenv())
# Out:
# [1] "author"  "options" "output"  "title"

# %%
ls.str(globalenv())
# Out:
# author :  chr "VN Pikachu"
# options :  chr "website"
# output :  chr "document: html_document"
# title :  chr "Environment in R"

# %%
# overwrite object `author` in global environment
assign('author', 'Nguyen Huu Trung', envir = globalenv())

# %%
ls.str(globalenv())
# Out:
# author :  chr "Nguyen Huu Trung"
# options :  chr "website"
# output :  chr "document: html_document"
# title :  chr "Environment in R"

# %% [markdown]
# # The active environment

# %% [markdown]
# At any moment of time, R is working closely with a single environment. R will store
# new objects in this environment (if you create any), and R will use this environment as
# a starting point to look up existing objects (if you call any). I’ll call this special
# environment the *active environment*. The active environment is usually the global en‐
# vironment, but this may change when you run a function.

# %% [markdown]
# >Use `environment()` too see the current active environment

# %%
# current active environment

environment()
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# The global environment plays a special role in R. It is the active environment for every
# command that you run at the command line. As a result, any object that you create at
# the command line will be saved in the global environment. You can think of the global
# environment as your user workspace. When you call an object at the command line, R will look for it first in the global envi‐
# ronment. But what if the object is not there? In that case, R will follow a series of rules
# to look up the object.

# %% [markdown]
# # Scoping Rules

# %% [markdown]
# R follows a special set of rules to look up objects. These rules are known as R’s scoping
# rules, and you’ve already met a couple of them:
# 1. R looks for objects in the current active environment.
# 2. When you work at the command line, the active environment is the global envi‐
# ronment. Hence, R looks up objects that you call at the command line in the global
# environment.
# 3. When R does not find an object in an environment, R looks in the environment’s
# parent environment, then the parent of the parent, and so on, until R finds the object
# or reaches the empty environment.

# %% [markdown]
# So, if you call an object at the command line, R will look for it in the global environment.
# If R can’t find it there, R will look in the parent of the global environment, and then the
# parent of the parent, and so on, working its way up the environment tree until it finds
# the object. If R cannot find the object in any environment, it will return
# an error that says the object is not found.

# %%
clan <- 'VN Champions'

print_clan <- function() print(clan)

print_clan()
# Out:
# [1] "VN Champions"

# %% [markdown]
# When we call `print_clan()`, a runtime environment will be created and R uses it as active environment. It will search for object named `clan` is the runtime environment, and it did not found. So it will move up to the parent of the runtime environment (in this case, the **global envronment**) and search for the object named `clan`. And it found an object named `clan` having value 'VN Champions' in the **global environment**. So the function will print the text "VN Champions"

# %% [markdown]
# # Assignment

# %% [markdown]
# When you assign a value to an object, R saves the value in the active environment under
# the object’s name. If an object with the same name already exists in the active environ‐
# ment, R will overwrite it.

# %%
# for example, an object named `author` exists in the global environment 
author
# Out:
# [1] "Nguyen Huu Trung"

# %% [markdown]
# You can save a new object named `author` to the global environment with this command. R
# will overwrite the old object as a result:

# %%
author <- 'VN Champions'

author
# Out:
# [1] "VN Champions"

# %% [markdown]
# This arrangement creates a quandry for R whenever R runs a function. Many functions
# save temporary objects that help them do their jobs.

# %%
# for example, this function saves an object named `author`
make_pdf <- function() {
    author <- 'Oreilly'
    author
}

# %% [markdown]
# R must save these temporary objects in the active environment; but if R does that, it
# may overwrite existing objects. Function authors cannot guess ahead of time which
# names may already exist in your active environment. How does R avoid this risk? Every
# time R runs a function, it creates a new active environment to evaluate the function in.

# %% [markdown]
# # Evaluation

# %% [markdown]
# R creates a new environment **each** time it evaluates a function. R will use the new en‐
# vironment as the active environment while it runs the function, and then R will return
# to the environment that you called the function from, bringing the function’s result with it. Let’s call these new environments runtime environments because R creates them at
# runtime to evaluate functions.

# %%
show_env <- function(format = 'pdf') {
    author <- 'Oreilly'
    
    list(
        # Return the environment when this function is running (the name of the runtime environment)
        runtime.env = environment(),
        # Return the parent of the environment when this function is running
        parent.env = parent.env(environment()),
        # objects in the environment that this function runs
        objects = ls.str(environment())
    )
}

# %% [markdown]
# `show_env` is a function. Each time we call `show_env()`, R will create an environment to evaluate the function in.

# %%
show_env()
# Out:
# $runtime.env
# <environment: 0x000000000510dfc8>
#
# $parent.env
# <environment: R_GlobalEnv>
#
# $objects
# author :  chr "Oreilly"
# format :  chr "pdf"

# %% [markdown]
# Just
# have `show_env` create some objects in its body of code. R will store any objects created
# by `show_env` in its runtime environment. Why? Because the runtime environment will
# be the active environment when those objects are created. This is how R ensures that a function does not overwrite anything that it shouldn’t. Any
# objects created by the function are stored in a safe, out-of-the-way runtime
# environment.
#
# R will also put a second type of object in a runtime environment. If a function has
# arguments, R will copy over each argument to the runtime environment. The argument
# will appear as an object that has the name of the argument but the value of whatever
# input the user provided for the argument. This ensures that a function will be able to
# find and use each of its arguments (the `format` arugment in the function `show_env`)

# %%
show_env()
# Out:
# $runtime.env
# <environment: 0x000000004177d6c0>
#
# $parent.env
# <environment: R_GlobalEnv>
#
# $objects
# author :  chr "Oreilly"
# format :  chr "pdf"

# %% [markdown]
# Now let’s consider which environment R will use as the parent of the runtime
# environment.
# R will connect a function’s runtime environment to the environment that the function
# was first created in. This environment plays an important role in the function’s life—
# because all of the function’s runtime environments will use it as a parent. Let’s call this
# environment the *origin environment*.

# %% [markdown]
# >You can look up a function’s origin environment
# by running **`environment`** on the function:

# %%
# origin environment of function `show_env`

environment(show_env)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# the parent of a runtime environment will not always be the global en‐
# vironment; it will be whichever environment the function was first created in.

# %% [markdown]
# ---

# %% [markdown]
# **SUMMARY**: Let’s put this all together to see how R evaluates a function. Before you call a function,
# R is working in an active environment; let’s call this the calling environment. It is the
# environment R calls the function from.
# Then you call the function. R responds by setting up a new runtime environment. This
# environment will be a child of the function’s origin enviornment. R will copy each of
# the function’s arguments into the runtime environment and then make the runtime
# environment the new active environment.
# Next, R runs the code in the body of the function. If the code creates any objects, R stores
# them in the active, that is, runtime environment. If the code calls any objects, R uses its
# scoping rules to look them up. R will search the runtime environment, then the parent
# of the runtime environment (which will be the origin environment), then the parent of
# the origin environment, and so on. Notice that the calling environment might not be
# on the search path. Usually, a function will only call its arguments, which R can find in
# the active runtime environment.
# Finally, R finishes running the function. It switches the active environment back to the
# calling environment. Now R executes any other commands in the line of code that called
# the function. So if you save the result of the function to an object with <-, the new object
# will be stored in the calling environment.
# To recap, R stores its objects in an environment system. At any moment of time, R is
# working closely with a single active environment. It stores new objects in this environ‐
# ment, and it uses the environment as a starting point when it searches for existing
# objects. R’s active environment is usually the global environment, but R will adjust the
# active environment to do things like run functions in a safe manner.

# %% [markdown]
# ---

# %%
ls.str(globalenv())
# Out:
# author :  chr "VN Champions"
# make_pdf : function ()
# options :  chr "website"
# output :  chr "document: html_document"
# show_env : function (format = "pdf")
# title :  chr "Environment in R"

# %% [markdown]
# >Task: Create a function that take the author name, and change the value of object named `author` in the global environment to that value.

# %%
# this will not work
# object `author` inside of the body function will be created in the runtime enviroment, not the global environment 
# when we call `set_author_wrong`

set_author_wrong <- function(name) author <- name

set_author_wrong('VN Pikachu')

author   # the value of object named `author` in the global environment did not change to 'VN Pikachu'
# Out:
# [1] "VN Champions"

# %%
# this will work
set_author_right <- function(name) assign('author', name, envir = globalenv())

set_author_right('Author\'s name is changed!')

author
# Out:
# [1] "Author's name is changed!"

# %% [markdown]
# # Closures

# %% [markdown]
# Read the book. It is very interesting.

# %% [markdown]
# ---

# %%
deck <- letters

# shuffle the deck
shuffle <- function() {
   
    assign('deck', deck[sample(1:length(deck))], envir = globalenv())
}

# Draw a random card from the deck
deal <- function() {
    
    res <- deck[[1]]
    assign('deck', deck[-1], envir = globalenv())
    res
}

# %%
shuffle()

# %%
deal()
# Out:
# [1] "o"

# %%
deal()
# Out:
# [1] "j"

# %%
shuffle()

# %%
length(deck)
# Out:
# [1] 21

# %%
deal()
# Out:
# [1] "t"

# %%
length(deck)
# Out:
# [1] 20

# %% [markdown]
# ---

# %% [markdown]
# What is the problem with the above approach? `deck` exists in the global environment. Lots of things happen in this environment, and it is possible that `deck` might get erased or modified by accident.

# %% [markdown]
# It would be better if we could store deck in a safe, out-of-the-way place, like one of those
# safe, out-of-the-way environments that R creates to run functions in. In fact, storing
# deck in a runtime environment is not such a bad idea

# %%
setup <- function(deck) {
    DECK <- deck
    
    deal <- function() {
        result <- DECK[[1]]
        assign('DECK', DECK[-1], envir = parent.env(environment()))
        result
    }
    
    shuffle <- function() {
        assign('DECK', DECK[sample(1:length(DECK))], envir = parent.env(environment()))
    }
    
    list(deal = deal, shuffle = shuffle)
}

cards <- setup(letters)

# %%
cards$shuffle()

# %%
cards$deal()
# Out:
# [1] "e"

# %%
cards$deal()
# Out:
# [1] "l"

# %%
cards$shuffle()

# %%
cards$deal()
# Out:
# [1] "p"

# %%
cards$deal()
# Out:
# [1] "i"

# %% [markdown]
# **How this works?**
# When you run setup, R will create a runtime environment to store these objects in. Their origin environment
# is no longer the global environment. Their origin environment is the runtime environment that R made when you
# ran `setup`. That’s where R created `DEAL` and `SHUFFLE`, the functions copied into the new
# `deal` and `shuffle`, as shown in:

# %%
environment(cards$deal)
# Out:
# <environment: 0x0000000009ed4188>

# %%
environment(cards$shuffle)
# Out:
# <environment: 0x0000000009ed4188>

# %% [markdown]
# This approach is called **Closures**

# %% [markdown]
# # Advanced R 2 edition

# %% [markdown]
# <b style = 'color:red'>MUST READ(Very comprehensive)</b>
# Environment chapter: <https://adv-r.hadley.nz/environments.html>

# %% [markdown]
# # Summary

# %% [markdown]
# R saves its objects in an environment system that resembles your computer’s file system.
# If you understand this system, you can predict how R will look up objects. If you call
# an object at the command line, R will look for the object in the global environment and
# then the parents of the global environment, working its way up the environment tree
# one environment at a time.
# R will use a slightly different search path when you call an object from inside of a func‐
# tion. When you run a function, R creates a new environment to execute commands in.
# This environment will be a child of the environment where the function was originally
# defined. This may be the global environment, but it also may not be. You can use this
# behavior to create closures, which are functions linked to objects in protected
# environments.
# As you become familiar with R’s environment system, you can use it to produce elegant
# results, like we did here. However, the real value of understanding the environment
# system comes from knowing how R functions do their job. You can use this knowledge
# to figure out what is going wrong when a function does not perform as expected.

# %% [markdown]
# ---
# ---

# %% [markdown]
# <img src = './environments.png'/>

# %% [markdown]
# Advanced R cheatsheet: <https://rstudio.com/wp-content/uploads/2016/02/advancedR.pdf>

# %%
# Current environment
environment()
# Out:
# <environment: R_GlobalEnv>

# %%
# search path
search()
# Out:
#  [1] ".GlobalEnv"        "jupyter:irkernel"  "package:stats"
#  [4] "package:graphics"  "package:grDevices" "package:utils"
#  [7] "package:datasets"  "package:methods"   "Autoloads"
# [10] "package:base"

# %%
# Loading new package: new package is attached right after global environment
library(purrr)
search()
# Out:
# Warning message:
# "package 'purrr' was built under R version 3.6.3"
#  [1] ".GlobalEnv"        "package:purrr"     "jupyter:irkernel"
#  [4] "package:stats"     "package:graphics"  "package:grDevices"
#  [7] "package:utils"     "package:datasets"  "package:methods"
# [10] "Autoloads"         "package:base"

# %%
# search path (following the arrow if a variable is not found in the environmen)
paste(search(), collapse = '-->')
# Out:
# [1] ".GlobalEnv-->package:purrr-->jupyter:irkernel-->package:stats-->package:graphics-->package:grDevices-->package:utils-->package:datasets-->package:methods-->Autoloads-->package:base"

# %%
# access environment "package:datasets" in the search path
as.environment('package:datasets')
# Out:
# <environment: package:datasets>
# attr(,"name")
# [1] "package:datasets"
# attr(,"path")
# [1] "C:/Users/dell/Anaconda3/Lib/R/library/datasets"
