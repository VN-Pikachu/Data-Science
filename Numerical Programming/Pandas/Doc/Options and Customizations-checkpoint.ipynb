# %%
import pandas as pd
import numpy as np 
import os
os.chdir(r'C:\Users\dell\PycharmProjects\MachineLearning\Pandas\datasets')

# %% [markdown]
# Pandas provide API to customize some aspects of its behavior, display is being mostly used.<br>
#
# The API is composed of five relevant functions. They are:<br>
#
# * get_option()
# * set_option()
# * reset_option()
# * describe_option()
# * option_context()

# %% [markdown]
# # get_option()

# %% [markdown]
# Available options:
#
# - compute.[use_bottleneck, use_numexpr]
# - display.[chop_threshold, colheader_justify, column_space, date_dayfirst,
#   date_yearfirst, encoding, expand_frame_repr, float_format]
# - display.html.[border, table_schema, use_mathjax]
# - display.[large_repr]
# - display.latex.[escape, longtable, multicolumn, multicolumn_format, multirow,
#   repr]
# - display.[max_categories, max_columns, max_colwidth, max_info_columns,
#   max_info_rows, max_rows, max_seq_items, memory_usage, multi_sparse,
#   notebook_repr_html, pprint_nest_depth, precision, show_dimensions]
# - display.unicode.[ambiguous_as_wide, east_asian_width]
# - display.[width]
# - html.[border]
# - io.excel.xls.[writer]
# - io.excel.xlsm.[writer]
# - io.excel.xlsx.[writer]
# - io.hdf.[default_format, dropna_table]
# - io.parquet.[engine]
# - mode.[chained_assignment, sim_interactive, use_inf_as_na, use_inf_as_null]
# - plotting.matplotlib.[register_converters]

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.get_option('display.width')
# Out:
# 80

# %% [markdown]
# # set_option()

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 5)

# %%
pokemon = pd.read_csv('./pokemon.csv')
pokemon
# Out:
#        #                   Name  ... Generation Legendary
# 0      1              Bulbasaur  ...          1     False
# 1      2                Ivysaur  ...          1     False
# 2      3               Venusaur  ...          1     False
# 3      3  VenusaurMega Venusaur  ...          1     False
# 4      4             Charmander  ...          1     False
# ..   ...                    ...  ...        ...       ...
# 795  719                Diancie  ...          6      True
# 796  719    DiancieMega Diancie  ...          6      True
# 797  720    HoopaHoopa Confined  ...          6      True
# 798  720     HoopaHoopa Unbound  ...          6      True
# 799  721              Volcanion  ...          6      True
#
# [800 rows x 13 columns]

# %% [markdown]
# # reset_option()

# %%
pd.reset_option('display.max_columns')
pd.get_option('display.max_columns')
# Out:
# 20

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # describe_option()

# %%
pd.describe_option('display.width')
# Out:
# display.width : int
#     Width of the display in characters. In case python/IPython is running in
#     a terminal this can be set to None and pandas will correctly auto-detect
#     the width.
#     Note that the IPython notebook, IPython qtconsole, or IDLE do not run in a
#     terminal and hence it is not possible to correctly detect the width.
#     [default: 80] [currently: 80]

# %% [markdown]
# # option_context()

# %%
with pd.option_context('display.max_rows', 20):
    print(pokemon)
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur    Grass  Poison    318   45      49
# 1      2                    Ivysaur    Grass  Poison    405   60      62
# 2      3                   Venusaur    Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur    Grass  Poison    625   80     100
# 4      4                 Charmander     Fire     NaN    309   39      52
# 5      5                 Charmeleon     Fire     NaN    405   58      64
# 6      6                  Charizard     Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# 9      7                   Squirtle    Water     NaN    314   44      48
# ..   ...                        ...      ...     ...    ...  ...     ...
# 790  714                     Noibat   Flying  Dragon    245   40      30
# ...

# %% [markdown]
# # Frequently used

# %% [markdown]
# 1
# <b>display.max_rows</b>
#
# Displays maximum number of rows to display
#
# 2
# <b>display.max_columns</b>
#
# Displays maximum number of columns to display
#
# 3
# <b>display.expand_frame_repr</b>
#
# Displays DataFrames to Stretch Pages
#
# 4
# <b>display.max_colwidth</b>
#
# Displays maximum column width
#
# 5
# <b>display.precision</b>
#
# Displays precision for decimal numbers

# %%
housing = pd.read_csv('./housing.csv')
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
with pd.option_context('display.precision', 2, 'display.max_columns', 6, 'display.width', 150):
    print(housing)
# Out:
#        longitude  latitude  housing_median_age  ...  median_income  median_house_value  ocean_proximity
# 0        -122.23     37.88                41.0  ...           8.33            452600.0         NEAR BAY
# 1        -122.22     37.86                21.0  ...           8.30            358500.0         NEAR BAY
# 2        -122.24     37.85                52.0  ...           7.26            352100.0         NEAR BAY
# 3        -122.25     37.85                52.0  ...           5.64            341300.0         NEAR BAY
# 4        -122.25     37.85                52.0  ...           3.85            342200.0         NEAR BAY
# ...          ...       ...                 ...  ...            ...                 ...              ...
# 20635    -121.09     39.48                25.0  ...           1.56             78100.0           INLAND
# 20636    -121.21     39.49                18.0  ...           2.56             77100.0           INLAND
# ...

# %%
pd.get_option('display.max_colwidth')
# Out:
# 50

# %%
with pd.option_context('display.max_colwidth', 10, 'display.max_columns', 5):
    print(pokemon)
# Out:
#        #       Name  ... Generation Legendary
# 0      1  Bulbasaur  ...          1     False
# 1      2    Ivysaur  ...          1     False
# 2      3   Venusaur  ...          1     False
# 3      3  Venusa...  ...          1     False
# 4      4  Charma...  ...          1     False
# ..   ...        ...  ...        ...       ...
# 795  719    Diancie  ...          6      True
# 796  719  Dianci...  ...          6      True
# 797  720  HoopaH...  ...          6      True
# 798  720  HoopaH...  ...          6      True
# 799  721  Volcanion  ...          6      True
#
# [800 rows x 13 columns]
