# %%
import seaborn as sns;
import pandas as pd

# %%
df = sns.load_dataset('tips')
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
table = df.pivot_table(values = ['size', 'tip'], index = ['day', 'time'], columns = ['smoker'],
                       fill_value = -1, aggfunc = 'sum', margins=True)
table.head(10)
# Out:
#             size               tip
# smoker       Yes   No  All     Yes      No     All
# day  time
# Thur Lunch    40  110  150   51.51  117.32  168.83
#      Dinner   -1    2    2   -1.00    3.00    3.00
# Fri  Lunch    11    3   14   13.68    3.00   16.68
#      Dinner   20    6   26   27.03    8.25   35.28
# Sat  Dinner  104  115  219  120.77  139.63  260.40
# Sun  Dinner   49  167  216   66.82  180.57  247.39
# All          224  403  627  279.81  451.77  731.58

# %% [markdown]
# # Example: Federal Election Commission Database

# %%
import os 
os.chdir(r'C:\Users\dell\Books\pydata-book-2nd-edition\datasets')

# %%
df = pd.read_csv('./fec/P00000001-ALL.csv')
df.info()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001731 entries, 0 to 1001730
# Data columns (total 16 columns):
# cmte_id              1001731 non-null object
# cand_id              1001731 non-null object
# cand_nm              1001731 non-null object
# contbr_nm            1001731 non-null object
# contbr_city          1001712 non-null object
# contbr_st            1001727 non-null object
# contbr_zip           1001620 non-null object
# contbr_employer      988002 non-null object
# contbr_occupation    993301 non-null object
# contb_receipt_amt    1001731 non-null float64
# contb_receipt_dt     1001731 non-null object
# receipt_desc         14166 non-null object
# memo_cd              92482 non-null object
# ...

# %%
df.head(3)
# Out:
#      cmte_id    cand_id             cand_nm        contbr_nm contbr_city  \
# 0  C00410118  P20002978  Bachmann, Michelle  HARVEY, WILLIAM      MOBILE
# 1  C00410118  P20002978  Bachmann, Michelle  HARVEY, WILLIAM      MOBILE
# 2  C00410118  P20002978  Bachmann, Michelle    SMITH, LANIER      LANETT
#
#   contbr_st   contbr_zip        contbr_employer      contbr_occupation  \
# 0        AL   3.6601e+08                RETIRED                RETIRED
# 1        AL   3.6601e+08                RETIRED                RETIRED
# 2        AL  3.68633e+08  INFORMATION REQUESTED  INFORMATION REQUESTED
#
#    contb_receipt_amt contb_receipt_dt receipt_desc memo_cd memo_text form_tp  \
# 0              250.0        20-JUN-11          NaN     NaN       NaN   SA17A
# 1               50.0        23-JUN-11          NaN     NaN       NaN   SA17A
# 2              250.0        05-JUL-11          NaN     NaN       NaN   SA17A
#
#    file_num
# 0    736166
# 1    736166
# 2    749073
