# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Out:
# Text(0.5, 1.0, '$\x07lpha$')
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# ...
