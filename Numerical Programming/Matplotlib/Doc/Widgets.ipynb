# %% [markdown]
# <a href = 'https://matplotlib.org/gallery/widgets/slider_demo.html' style='font-size:30px'>Widget Tutorial</a>

# %%
import matplotlib.pyplot as plt
from matplotlib import widgets

# %%
from matplotlib.widgets import TextBox, Button, Slider, RadioButtons

# %%
import numpy as np

# %%
help(widgets)
# Out:
# Help on module matplotlib.widgets in matplotlib:
#
# NAME
#     matplotlib.widgets
#
# DESCRIPTION
#     GUI neutral widgets
# ...
#
#     Widgets that are designed to work for any of the GUI backends.
#     All of these widgets require you to predefine a :class:`matplotlib.axes.Axes`
#     instance and pass that as the first arg.  matplotlib doesn't try to
#     be too smart with respect to layout -- you will have to figure out how
#     wide and tall you want your Axes to be to accommodate your widget.
#
# CLASSES
#     builtins.object
#         LockDraw
#         ToolHandles
#         Widget
#             AxesWidget
#                 Button
#                 CheckButtons
#                 Cursor
#                 Lasso
#                 RadioButtons
#                 Slider
#                 TextBox
#             MultiCursor
#             SubplotTool
#     _SelectorWidget(AxesWidget)
#         LassoSelector
#         PolygonSelector
#         RectangleSelector
# ...

# %% [markdown]
# # Slider

# %% [markdown]
# ```python
# Slider(
#     ax,
#     label,
#     valmin,
#     valmax,
#     valinit=0.5,
#     valfmt='%1.2f',
#     closedmin=True,
#     closedmax=True,
#     slidermin=None,
#     slidermax=None,
#     dragging=True,
#     valstep=None,
#     orientation='horizontal',
#     **kwargs,
# )
# ```

# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button, RadioButtons

fig, ax = plt.subplots()
plt.subplots_adjust(left=0.25, bottom=0.25)
t = np.arange(0.0, 1.0, 0.001)
a0 = 5
f0 = 3
delta_f = 5.0
s = a0 * np.sin(2 * np.pi * f0 * t)
l, = plt.plot(t, s, lw=2)
ax.margins(x=0)

axcolor = 'lightgoldenrodyellow'
axfreq = plt.axes([0.25, 0.1, 0.65, 0.03], facecolor=axcolor)
axamp = plt.axes([0.25, 0.15, 0.65, 0.03], facecolor=axcolor)

sfreq = Slider(axfreq, 'Freq', 0.1, 30.0, valinit=f0, valstep=delta_f)
samp = Slider(axamp, 'Amp', 0.1, 10.0, valinit=a0)


def update(val):
    amp = samp.val
    freq = sfreq.val
    l.set_ydata(amp*np.sin(2*np.pi*freq*t))
    fig.canvas.draw_idle()


sfreq.on_changed(update)
samp.on_changed(update)

resetax = plt.axes([0.8, 0.025, 0.1, 0.04])
button = Button(resetax, 'Reset', color=axcolor, hovercolor='0.975')


def reset(event):
    sfreq.reset()
    samp.reset()
button.on_clicked(reset)

rax = plt.axes([0.025, 0.5, 0.15, 0.15], facecolor=axcolor)
radio = RadioButtons(rax, ('red', 'blue', 'green'), active=0)


def colorfunc(label):
    l.set_color(label)
    fig.canvas.draw_idle()
radio.on_clicked(colorfunc)

# Initialize plot with correct initial active value
colorfunc(radio.value_selected)

# %% [markdown]
# # Using Widgets in Ipython Notebook

# %% [markdown]
# <a href = 'https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html' style='font-size:30px'>ipywidgets tutorial</a>

# %%
import ipywidgets

# %%
from ipywidgets import interact

# %%
def f(x):
    print(f'Hello, {x}!')
    
interact(f, x = '')
# Out:
# interactive(children=(Text(value='', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.f(x)>
